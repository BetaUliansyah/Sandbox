# %% [markdown]
# <a href="https://colab.research.google.com/github/BetaUliansyah/Sandbox/blob/main/Sinta_Hunter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sinta Hunter
#
# Author: Beta Uiansyah, <beta.uliansyah@pknstan.ac.id>
#
# Halaman notebook ini berisi skrip-skrip python yang saya gunakan untuk mencoba mendapatkan data seluruh jurnal terakreditasi Sinta yang tersedia di alamat sinta.ristekbrin.go.id dengan teknik web scrapping.
#
# Skrip Sinta Hunter adalah bagian pertama dan utama dari [sinta-tools](https://github.com/BetaUliansyah/sinta-tools). Sinta Tools direncakan terdiri dari:
# - Sinta Hunter
# - CFP Hunter (mungkin berupa dashboard menggunakan [datastudio.google.com](https://datastudio.google.com))
# - Reviewers Hunter
#
# Skrip Sinta Hunter memiliki 4 varian:
# 1. [output ke layar](#scrollTo=hPs3_V7rNsWN&line=3&uniqifier=1)
# 2. [output berupa return value dengan format json](#scrollTo=BV2p2nNBfkER) (belum berjalan dengan baik)
# 3. [output berupa file dengan format csv](#scrollTo=dJy2ei3N2n7A) (versi terbaik saat ini)
# 4. [output berupa file dengan format csv tersimpan di Google Drive](#scrollTo=YaazQkWbIXnv) sehingga bisa dijalankan di colab
#
# Data scrapping berformat csv dapat dilihat di [https://github.com/BetaUliansyah/sinta-tools/blob/master/sinta-data-2020-03-17.csv](https://github.com/BetaUliansyah/sinta-tools/blob/master/sinta-data-2020-03-17.csv)

# %% [markdown]
# # Sinta Hunter Beta Release

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import json
import re

def sinta_readpages(startpage, lastpage):
    # looping halaman Sinta dari startpage sampai lastpage
    return_value = {}
    currentpage = startpage
    journal_no = (startpage-1) * 9 + 1
    i = 0
    while currentpage < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 620:
        #    break
        
        s = requests.Session()
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(currentpage) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            # mencari nama jurnal
            journal_link = journal.find('a')

            #mencari akreditasi
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            #print(str(journal_no) + ". " + journal_link.text)
            #print("   Akreditasi: " + journal_info.text)

            # mencari affiliation
            #journal_affiliation = journal.find('dd')
            #if journal_affiliation is None:
            #    journal_affiliation = ''
            #print(journal_affiliation.text)

            # mencari area tema jurnal
            #journal_topic = journal.find('a', attrs={'class': 'area-item-small'})
            #if journal_topic is None:
            #    str_journal_topic = ''
            #else:
            #    str_journal_topic = journal_topic.text
            
            # mencari URL jurnal
            r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            if r.status_code==200:
                jsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                
                # mencari URL
                journal_urls = jsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                #print("   URL: " + journal_url)
            return_value[i] = {
                'journal_no': journal_no,
                'journal_name': journal_link.text, 
                'journal_accreditation': journal_info.text, 
                #'journal_affiliation': journal_affiliation, 
                #'journal_topic': str_journal_topic, 
                'journal_url': journal_url
                }
            journal_no = journal_no +1
            i += 1
            
        currentpage = currentpage + 1
    return json.dumps(return_value)


def sinta_lastpage():
    """
    Find last page of Sinta list
    """
    s = requests.Session()
    r = s.get('http://sinta.ristekbrin.go.id/journals')
    bsoup = BeautifulSoup(r.text, 'html.parser')
    lastpage = 1

    if r.status_code==200:
        # mencari halaman terakhir
        for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
            for litag in ultag.find_all('li'):
                for links in litag.find_all('a', href=True):
                    # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                    # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                    query = urlparse(links['href']).query
                    lastpage = re.compile('page=(\d+)').findall(query)
        lastpage = int(lastpage[0])
    return lastpage

def main(startpage=1, lastpage=sinta_lastpage()):
    """
    Run sinta-hunter with 2 arguments: start and last page
    """
    return_value = sinta_readpages(startpage, lastpage)
    return return_value
  
main(startpage=3, lastpage=4)
# main(lastpage=4)
# main(startpage=3, lastpage=4)


# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# '{"0": {"journal_no": 19, "journal_name": "Tropical Animal Science Journal", "journal_accreditation": "S1", "journal_url": "http://journal.ipb.ac.id/index.php/mediapeternakan"}, "1": {"journal_no": 20, "journal_name": "International Journal of Renewable Energy Development : JRED", "journal_accreditation": "S1", "journal_url": "http://ejournal.undip.ac.id/index.php/ijred/index"}, "2": {"journal_no": 21, "journal_name": "Indonesian Journal of Electrical Engineering and Computer Science", "journal_accreditation": "S1", "journal_url": "http://www.iaesjournal.com/online/index.php/IJEECS"}, "3": {"journal_no": 22, "journal_name": "Indonesian Journal of Electrical Engineering and Informatics", "journal_accreditation": "S1", "journal_url": "http://section.iaesonline.com/index.php/IJEEI/index"}, "4": {"journal_no": 23, "journal_name": "TELKOMNIKA (Telecommunication Computing Electronics and Control)", "journal_accreditation": "S1", "journal_url": "http://journal.uad.ac.id/index.php/telkomnika"}, "5": {"journal_no": 24, "journal_name": "IJOG : Indonesian Journal on Geoscience", "journal_accreditation": "S1", "journal_url": "https://ijog.geologi.esdm.go.id/index.php/IJOG"}, "6": {"journal_no": 25, "journal_name": "QIJIS (Qudus International Journal Of Islamic Studies)", "journal_accreditation": "S1", "journal_url": "http://journal.stainkudus.ac.id/index.php/QIJIS"}, "7": {"journal_no": 26, "journal_name": "Atom Indonesia", "journal_accreditation": "S1", "journal_url": "http://aij.batan.go.id"}, "8": {"journal_no": 27, "journal_name": "AGRIVITA, Journal of Agricultural Science (AJAS)", "journal_accreditation": "S1", "journal_url": "https://agrivita.ub.ac.id/index.php/agrivita"}, "9": {"journal_no": 28, "journal_name": "HAYATI Journal of Biosciences", "journal_accreditation": "S1", "journal_url": "http://journal.ipb.ac.id/index.php/hayati/"}, "10": {"journal_no": 29, "journal_name": "Journal of Degraded and Mining Lands Management", "journal_accreditation": "S1", "journal_url": "http://jdmlm.ub.ac.id/index.php/jdmlm/index"}, "11": {"journal_no": 30, "journal_name": "JSP (Jurnal Ilmu Sosial dan Ilmu Politik)", "journal_accreditation": "S1", "journal_url": "https://jurnal.ugm.ac.id/index.php/jsp"}, "12": {"journal_no": 31, "journal_name": "Indonesian Journal of Chemistry", "journal_accreditation": "S1", "journal_url": "https://jurnal.ugm.ac.id/ijc"}, "13": {"journal_no": 32, "journal_name": "BIOTROPIA", "journal_accreditation": "S1", "journal_url": "http://journal.biotrop.org/index.php/biotropia"}, "14": {"journal_no": 33, "journal_name": "Indonesian Journal of Biotechnology", "journal_accreditation": "S1", "journal_url": "https://jurnal.ugm.ac.id/ijbiotech/"}, "15": {"journal_no": 34, "journal_name": "Al-Jami\'ah: Journal of Islamic Studies", "journal_accreditation": "S1", "journal_url": "http://www.aljamiah.or.id"}, "16": {"journal_no": 35, "journal_name": "Bulletin of Chemical Reaction Engineering & Catalysis", "journal_accreditation": "S1", "journal_url": "https://ejournal2.undip.ac.id/index.php/bcrec"}, "17": {"journal_no": 36, "journal_name": "Journal of Regional and City Planning", "journal_accreditation": "S1", "journal_url": "http://journals.itb.ac.id/index.php/jpwk"}, "18": {"journal_no": 37, "journal_name": "Indonesian Journal of Forestry Research", "journal_accreditation": "S1", "journal_url": "http://ejournal.forda-mof.org/ejournal-litbang/index.php/IJFR"}, "19": {"journal_no": 38, "journal_name": "Indonesian Journal of Geography", "journal_accreditation": "S1", "journal_url": "http://jurnal.ugm.ac.id/ijg/"}}'

# %% [markdown]
# # Sinta Hunter CSV

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import re
import csv
from datetime import date

def sinta_lastpage():
    """
    Find last page of Sinta list
    """
    s = requests.Session()
    r = s.get('https://sinta.ristekbrin.go.id/journals')
    bsoup = BeautifulSoup(r.text, 'html.parser')
    lastpage = 1

    if r.status_code==200:
        # mencari halaman terakhir
        for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
            for litag in ultag.find_all('li'):
                for links in litag.find_all('a', href=True):
                    # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                    # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                    query = urlparse(links['href']).query
                    lastpage = re.compile('page=(\d+)').findall(query)
        lastpage = int(lastpage[0])
    return lastpage

def sinta_readpages(startpage=1, lastpage=sinta_lastpage()):
    # prepare file name with date and write header
    filename = "sinta-data-" + str(date.today()) + ".csv"
    header_row = ['journal_no', 'journal_name', 'journal_accreditation', 'journal_url']
    with open(filename, mode='w') as sintacsv_file:
        sintacsv_writer = csv.writer(sintacsv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        sintacsv_writer.writerow(header_row)
    print(header_row)

    # looping halaman Sinta dari startpage sampai lastpage
    return_value = []
    currentpage = startpage
    journal_no = (startpage-1) * 9 + 1
    i = 0
    while currentpage < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 620:
        #    break

        # session
        s = requests.Session()
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(currentpage) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            # mencari nama jurnal
            journal_link = journal.find('a')

            #mencari akreditasi
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            
            # mencari URL jurnal
            r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            if r.status_code==200:
                jsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                
                # mencari URL
                journal_urls = jsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                #print("   URL: " + journal_url)
                
            # prepare result_data
            result_data = [journal_no, journal_link.text, journal_info.text, journal_url]
            with open(filename, mode='a+') as sintacsv_file:
                sintacsv_writer = csv.writer(sintacsv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
                sintacsv_writer.writerow(result_data)
            return_value.append(result_data)
            print(result_data)
            journal_no = journal_no +1
            i += 1
            
        currentpage = currentpage + 1
    return return_value

if __name__ == "__main__":
    sinta_readpages()
    # sinta_readpages(startpage=3, lastpage=4)
    # sinta_readpages(7, 8)




# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# ['journal_no', 'journal_name', 'journal_accreditation', 'journal_url']
# [55, 'Electronic Journal of Graph Theory and Applications', 'S1', 'http://www.ejgta.org/index.php/ejgta']
# [56, 'Kukila', 'S1', 'http://kukila.org/index.php/KKL']
# [57, 'International Journal of Technology', 'S1', 'http://www.ijtech.eng.ui.ac.id/old/index.php/journal']
# [58, 'Critical Care and Shock', 'S1', 'http://criticalcareshock.org/']
# [59, 'Forum Penelitian Agro Ekonomi', 'S2', 'http://ejurnal.litbang.pertanian.go.id/index.php/fae']
# [60, 'Jurnal Aplikasi Manajemen', 'S2', 'http://jurnaljam.ub.ac.id/index.php/jam/index']
# [61, 'Jurnal Penelitian Pascapanen Pertanian', 'S2', 'http://ejurnal.litbang.pertanian.go.id/index.php/jpasca']
# [62, 'Jurnal Agronomi Indonesia (Indonesian Journal of Agronomy)', 'S2', 'http://journal.ipb.ac.id/index.php/jurnalagronomi']
# [63, 'Berita Biologi', 'S2', 'http://e-journal.biologi.lipi.go.id/index.php/berita_biologi']
# [64, 'Jurnal Ekologi Kesehatan', 'S2', 'http://ejournal.litbang.depkes.go.id/index.php/jek/issue/archive']
# [65, 'Riset Akuntansi dan Keuangan Indonesia', 'S2', 'http://journals.ums.ac.id/index.php/reaksi']
# [66, 'Marine Research In Indonesia', 'S2', 'http://mrijournal.or.id/index.php/MRI']
# [67, 'KEMAS : Jurnal Kesehatan Masyarakat', 'S2', 'http://journal.unnes.ac.id/nju/index.php/kemas']
# [68, 'Buletin Plasma Nutfah', 'S2', 'http://ejurnal.litbang.pertanian.go.id/index.php/bpn']
# [69, 'Jurnal Ilmu Teknologi Kayu Tropis', 'S2', 'http://ejournalmapeki.org/index.php/JITKT']
# [70, 'JOIN (Jurnal Online Informatika)', 'S2', 'http://join.if.uinsgd.ac.id/index.php/join']
# [71, 'Buletin Penelitian Tanaman Rempah dan Obat', 'S2', 'http://ejurnal.litbang.pertanian.go.id/index.php/bultro']
# [72, 'Analisis Kebijakan Pertanian', 'S2', 'http://ejurnal.litbang.pertanian.go.id/index.php/akp']
# [73, 'Biosfer: Jurnal Pendidikan Biologi', 'S2', 'http://journal.unj.ac.id/unj/index.php/biosfer/index']
# [74, 'Tadris: Jurnal keguruan dan Ilmu Tarbiyah', 'S2', 'http://ejournal.radenintan.ac.id/index.php/tadris']

# %% [markdown]
# # Sinta Hunter json

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import json
import re

def sinta_readpages(startpage, lastpage):
    # looping halaman Sinta dari startpage sampai lastpage
    return_value = []
    return_value.append(['journal_no', 'journal_name', 'journal_accreditation', 'journal_url'])
    currentpage = startpage
    journal_no = (startpage-1) * 9 + 1
    while currentpage < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 620:
        #    break
        
        s = requests.Session()
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(currentpage) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            # mencari nama jurnal
            journal_link = journal.find('a')

            #mencari akreditasi
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            #print(str(journal_no) + ". " + journal_link.text)
            #print("   Akreditasi: " + journal_info.text)

            # mencari affiliation
            #journal_affiliation = journal.find('dd')
            #if journal_affiliation is None:
            #    journal_affiliation = ''
            #print(journal_affiliation.text)

            # mencari area tema jurnal
            #journal_topic = journal.find('a', attrs={'class': 'area-item-small'})
            #if journal_topic is None:
            #    str_journal_topic = ''
            #else:
            #    str_journal_topic = journal_topic.text
            
            # mencari URL jurnal
            r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            if r.status_code==200:
                jsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                
                # mencari URL
                journal_urls = jsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                #print("   URL: " + journal_url)
            return_value.append([journal_no, 
                journal_link.text, 
                journal_info.text, 
                journal_url
            ])
            journal_no = journal_no +1
            
        currentpage = currentpage + 1
    return json.dumps(return_value, indent=None)


def sinta_lastpage():
    """
    Find last page of Sinta list
    """
    s = requests.Session()
    r = s.get('http://sinta.ristekbrin.go.id/journals')
    bsoup = BeautifulSoup(r.text, 'html.parser')
    lastpage = 1

    if r.status_code==200:
        # mencari halaman terakhir
        for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
            for litag in ultag.find_all('li'):
                for links in litag.find_all('a', href=True):
                    # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                    # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                    query = urlparse(links['href']).query
                    lastpage = re.compile('page=(\d+)').findall(query)
        lastpage = int(lastpage[0])
    return lastpage

def main(startpage=1, lastpage=sinta_lastpage()):
    """
    Run sinta-hunter with 2 arguments: start and last page
    """
    return_value = sinta_readpages(startpage, lastpage)
    return return_value
  
main(startpage=3, lastpage=4)
# Example arguments
# main(lastpage=4)
# main(startpage=3, lastpage=4)


# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# '[["journal_no", "journal_name", "journal_accreditation", "journal_url"], [19, "Tropical Animal Science Journal", "S1", "http://journal.ipb.ac.id/index.php/mediapeternakan"], [20, "International Journal of Renewable Energy Development : JRED", "S1", "http://ejournal.undip.ac.id/index.php/ijred/index"], [21, "Indonesian Journal of Electrical Engineering and Computer Science", "S1", "http://www.iaesjournal.com/online/index.php/IJEECS"], [22, "Indonesian Journal of Electrical Engineering and Informatics", "S1", "http://section.iaesonline.com/index.php/IJEEI/index"], [23, "TELKOMNIKA (Telecommunication Computing Electronics and Control)", "S1", "http://journal.uad.ac.id/index.php/telkomnika"], [24, "IJOG : Indonesian Journal on Geoscience", "S1", "https://ijog.geologi.esdm.go.id/index.php/IJOG"], [25, "QIJIS (Qudus International Journal Of Islamic Studies)", "S1", "http://journal.stainkudus.ac.id/index.php/QIJIS"], [26, "Atom Indonesia", "S1", "http://aij.batan.go.id"], [27, "AGRIVITA, Journal of Agricultural Science (AJAS)", "S1", "https://agrivita.ub.ac.id/index.php/agrivita"], [28, "HAYATI Journal of Biosciences", "S1", "http://journal.ipb.ac.id/index.php/hayati/"], [29, "Journal of Degraded and Mining Lands Management", "S1", "http://jdmlm.ub.ac.id/index.php/jdmlm/index"], [30, "JSP (Jurnal Ilmu Sosial dan Ilmu Politik)", "S1", "https://jurnal.ugm.ac.id/index.php/jsp"], [31, "Indonesian Journal of Chemistry", "S1", "https://jurnal.ugm.ac.id/ijc"], [32, "BIOTROPIA", "S1", "http://journal.biotrop.org/index.php/biotropia"], [33, "Indonesian Journal of Biotechnology", "S1", "https://jurnal.ugm.ac.id/ijbiotech/"], [34, "Al-Jami\'ah: Journal of Islamic Studies", "S1", "http://www.aljamiah.or.id"], [35, "Bulletin of Chemical Reaction Engineering & Catalysis", "S1", "https://ejournal2.undip.ac.id/index.php/bcrec"], [36, "Journal of Regional and City Planning", "S1", "http://journals.itb.ac.id/index.php/jpwk"], [37, "Indonesian Journal of Forestry Research", "S1", "http://ejournal.forda-mof.org/ejournal-litbang/index.php/IJFR"], [38, "Indonesian Journal of Geography", "S1", "http://jurnal.ugm.ac.id/ijg/"]]'

# %% [markdown]
# # Sinta Hunter versi 1.1 (text to stdout)

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import json
import re


s = requests.Session()
r = s.get('http://sinta.ristekbrin.go.id/journals')
bsoup = BeautifulSoup(r.text, 'html.parser')
lastpage = 1

if r.status_code==200:
    # mencari halaman terakhir
    for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
        for litag in ultag.find_all('li'):
            for links in litag.find_all('a', href=True):
                # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                query = urlparse(links['href']).query
                lastpage = re.compile('page=(\d+)').findall(query)
    lastpage = lastpage[0]
    print("Bismillah, lets start srcapping " + lastpage + " pages of Sinta journals")

    # looping halaman Sinta sampai lastpage
    page = 1
    journal_no = 1
    while page < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 2:
        #    break
        
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(page) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            journal_link = journal.find('a')
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            print(str(journal_no) + ". " + journal_link.text)
            print("   Akreditasi: " + journal_info.text)
            
            r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            if r.status_code==200:
                bsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                journal_urls = bsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                print("   URL: " + journal_url)
            journal_no = journal_no +1
            
        page = page + 1



# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# Streaming output truncated to the last 5000 lines.
#    Akreditasi: S2
#    URL: http://journal.walisongo.ac.id/index.php/ahkam/index
# 617. Jurnal Pendidikan Islam
#    Akreditasi: S2
#    URL: http://ejournal.uin-suka.ac.id/tarbiyah/JPI
# 618. Etnosia : Jurnal Etnografi Indonesia
#    Akreditasi: S2
#    URL: http://journal.unhas.ac.id/index.php/etnosia
# 619. Jurnal Sumberdaya Lahan
#    Akreditasi: S2
#    URL: http://ejurnal.litbang.pertanian.go.id/index.php/jsl
# 620. Jurnal Media Hukum
#    Akreditasi: S2
#    URL: http://journal.umy.ac.id/index.php/jmh
# 621. Jurnal Adabiyah
#    Akreditasi: S2
#    URL: http://journal.uin-alauddin.ac.id/index.php/adabiyah
# 622. Majalah Ilmiah Pengkajian Industri
#    Akreditasi: S2
#    URL: http://ejurnal.bppt.go.id/index.php/MIPI/index
# 623. Kontekstualita : Jurnal Penelitian Sosial Keagamaan
#    Akreditasi: S2
#    URL: http://e-journal.lp2m.uinjambi.ac.id/ojp/index.php/Kontekstualita/index
# 624. Majalah Kedokteran Gigi Indonesia
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/mkgi
# 625. Jurnal Penelitian Transportasi Multimoda
#    Akreditasi: S2
#    URL: http://ojs.balitbanghub.dephub.go.id/index.php/jurnalmtm
# 626. Inovasi : Jurnal Politik dan Kebijakan
#    Akreditasi: S2
#    URL: http://jurnal.balitbang.sumutprov.go.id/index.php/inovasi
# 627. Berkala Arkeologi
#    Akreditasi: S2
#    URL: http://berkalaarkeologi.kemdikbud.go.id/index.php/berkalaarkeologi
# 628. Patrawidya
#    Akreditasi: S2
#    URL: https://patrawidya.kemdikbud.go.id/index.php/patrawidya
# 629. JAI (Jurnal Anestesiologi Indonesia)
#    Akreditasi: S2
#    URL: https://ejournal.undip.ac.id/index.php/janesti
# 630. Jurnal Penelitian dan Pengembangan Pertanian
#    Akreditasi: S2
#    URL: http://ejurnal.litbang.pertanian.go.id/index.php/jppp
# 631. Jurnal Manajemen dan Kewirausahaan
#    Akreditasi: S2
#    URL: http://jurnalmanajemen.petra.ac.id
# 632. Jurnal Akuntansi dan Keuangan
#    Akreditasi: S2
#    URL: http://jurnalakuntansi.petra.ac.id
# 633. Jurnal Akuntansi dan Keuangan Indonesia
#    Akreditasi: S2
#    URL: http://jaki.ui.ac.id/index.php/home/index
# 634. JURNAL PSIKOLOGI
#    Akreditasi: S2
#    URL: https://ejournal.undip.ac.id/index.php/psikologi/index
# 635. Jurnal Gizi dan Pangan
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/jgizipangan
# 636. Civil Engineering Dimension
#    Akreditasi: S2
#    URL: http://ced.petra.ac.id
# 637. Jurnal Ilmu dan Teknologi Kelautan Tropis
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/jurnalikt
# 638. Jurnal Veteriner : Jurnal Kedokteran Hewan Indonesia
#    Akreditasi: S2
#    URL: http://ojs.unud.ac.id/index.php/jvet
# 639. BISNIS & BIROKRASI : Jurnal Ilmu Administrasi dan Organisasi
#    Akreditasi: S2
#    URL: http://journal.ui.ac.id/index.php/jbb/issue/archive
# 640. Saintek Perikanan : Indonesian Journal of Fisheries Science and Technology
#    Akreditasi: S2
#    URL: https://ejournal.undip.ac.id/index.php/saintek
# 641. Jurnal Pengajaran MIPA
#    Akreditasi: S2
#    URL: http://journal.fpmipa.upi.edu/index.php/jpmipa/index
# 642. Jurnal Dinamika Akuntansi
#    Akreditasi: S2
#    URL: https://journal.unnes.ac.id/nju/index.php/jda
# 643. Pharmaceutical Sciences and Research (PSR)
#    Akreditasi: S2
#    URL: http://psr.ui.ac.id/index.php/journal
# 644. Jurnal Economia
#    Akreditasi: S2
#    URL: https://journal.uny.ac.id/index.php/economia/
# 645. Jurnal Pendidikan Indonesia
#    Akreditasi: S2
#    URL: http://ejournal.undiksha.ac.id/index.php/JPI/index
# 646. MIMBAR HUKUM
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/jmh/index
# 647. Jurnal Pendidikan Matematika
#    Akreditasi: S2
#    URL: http://ejournal.unsri.ac.id/index.php/jpm
# 648. Komunitas: International Journal of Indonesian Society and Culture
#    Akreditasi: S2
#    URL: http://journal.unnes.ac.id/nju/index.php/komunitas
# 649. Jurnal Konstitusi
#    Akreditasi: S2
#    URL: http://ejournal.mahkamahkonstitusi.go.id/index.php/jk/index
# 650. Dinamika Pendidikan
#    Akreditasi: S2
#    URL: https://journal.unnes.ac.id/nju/index.php/DP
# 651. Jurnal Sistem Informasi (Journal of Information System)
#    Akreditasi: S2
#    URL: http://jsi.cs.ui.ac.id/index.php/jsi
# 652. EDUSAINS
#    Akreditasi: S2
#    URL: http://journal.uinjkt.ac.id/index.php/edusains/index
# 653. Jurnal Ilmu Komunikasi
#    Akreditasi: S2
#    URL: https://ojs.uajy.ac.id/index.php/jik
# 654. Depik Jurnal Ilmu-Ilmu Perairan, Pesisir dan Perikanan
#    Akreditasi: S2
#    URL: http://jurnal.unsyiah.ac.id/depik
# 655. Gizi Indonesia
#    Akreditasi: S2
#    URL: http://ejournal.persagi.org/ojspersagi2481/index.php/Gizi_Indon
# 656. Jurnal Kesehatan Reproduksi
#    Akreditasi: S2
#    URL: http://ejournal.litbang.depkes.go.id/index.php/kespro/issue/archive
# 657. k@ta
#    Akreditasi: S2
#    URL: http://kata.petra.ac.id
# 658. Jurnal Ilmu Kefarmasian Indonesia
#    Akreditasi: S2
#    URL: http://jifi.farmasi.univpancasila.ac.id/
# 659. Jurnal Penelitian Sosial dan Ekonomi Kehutanan
#    Akreditasi: S2
#    URL: http://ejournal.forda-mof.org/ejournal-litbang/index.php/JPSEK
# 660. Anima
#    Akreditasi: S2
#    URL: http://www.anima.ubaya.ac.id/
# 661. Jurnal Agripet
#    Akreditasi: S2
#    URL: http://jurnal.unsyiah.ac.id/agripet
# 662. Jurnal Teknik Sipil
#    Akreditasi: S2
#    URL: http://journals.itb.ac.id/index.php/jts
# 663. MASYARAKAT: Jurnal Sosiologi
#    Akreditasi: S2
#    URL: http://journal.ui.ac.id/index.php/mjs/index
# 664. Jurnal Reaktor
#    Akreditasi: S2
#    URL: http://ejournal.undip.ac.id/index.php/reaktor
# 665. Sosio Informa
#    Akreditasi: S2
#    URL: https://ejournal.kemsos.go.id/index.php?journal=Sosioinforma
# 666. DIMENSI: Journal of Architecture and Built Environment
#    Akreditasi: S2
#    URL: http://dimensi.petra.ac.id
# 667. Media Gizi Indonesia
#    Akreditasi: S2
#    URL: https://e-journal.unair.ac.id/MGI
# 668. Informatika Pertanian
#    Akreditasi: S2
#    URL: http://ejurnal.litbang.pertanian.go.id/index.php/IP
# 669. Jurnal Teknik Industri : Jurnal Keilmuan dan Aplikasi Teknik Industri
#    Akreditasi: S2
#    URL: http://jurnalindustri.petra.ac.id
# 670. Psikopedagogia
#    Akreditasi: S2
#    URL: http://journal.uad.ac.id/index.php/PSIKOPEDAGOGIA
# 671. Jurnal Teknologi Pertanian
#    Akreditasi: S2
#    URL: http://jtp.ub.ac.id/index.php/jtp/index
# 672. Jurnal Hama dan Penyakit Tumbuhan Tropika
#    Akreditasi: S2
#    URL: http://journal.unila.ac.id/index.php/jhtrop; http://jhpttropika.fp.unila.ac.id
# 673. Jurnal Perspektif Pembiayaan dan Pembangunan Daerah
#    Akreditasi: S2
#    URL: https://online-journal.unja.ac.id/index.php/JES
# 674. Al-Ulum
#    Akreditasi: S2
#    URL: http://journal.iaingorontalo.ac.id/index.php/au/index
# 675. The Indonesian Journal of Gastroenterology, Hepatology and Digestive Endoscopy
#    Akreditasi: S2
#    URL: http://ina-jghe.com/journal/index.php/jghe
# 676. Sodality : Jurnal Sosiologi Pedesaan
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/sodality
# 677. Berkala Penelitian Hayati (Journal of Biological Researchers)
#    Akreditasi: S2
#    URL: http://berkalahayati.org/home
# 678. Jurnal Sains & Teknologi Modifikasi Cuaca
#    Akreditasi: S2
#    URL: http://ejurnal.bppt.go.id/index.php/JSTMC/index
# 679. Jurnal Hukum & Pembangunan
#    Akreditasi: S2
#    URL: http://jhp.ui.ac.id/index.php/home
# 680. Folia Medica Indonesiana
#    Akreditasi: S2
#    URL: http://e-journal.unair.ac.id/index.php/FMI
# 681. Journal of the Indonesian Mathematical Society
#    Akreditasi: S2
#    URL: https://www.jims-a.org/index.php/jimsa
# 682. Journal of Tropical Life Science : International Journal of Theoretical, Experimental, and Applied Life Sciences
#    Akreditasi: S2
#    URL: http://jtrolis.ub.ac.id/index.php/jtrolis/index
# 683. Asy-Syir'ah Jurnal Ilmu Syari'ah dan Hukum
#    Akreditasi: S2
#    URL: http://asy-syirah.uin-suka.com/index.php/AS
# 684. JTEP (Jurnal Keteknikan Pertanian)
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/jtep
# 685. Jurnal Hortikultura Indonesia (JHI)
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/jhi/index
# 686. Agrointek : Jurnal Teknologi Industri Pertanian
#    Akreditasi: S2
#    URL: http://journal.trunojoyo.ac.id/agrointek/index
# 687. Jurnal Rechts Vinding : Media Pembinaan Hukum Nasional
#    Akreditasi: S2
#    URL: http://www.rechtsvinding.bphn.go.id/ejournal/index.php/jrv
# 688. Reinwardtia
#    Akreditasi: S2
#    URL: http://e-journal.biologi.lipi.go.id/index.php/reinwardtia/index
# 689. KARSA: Jurnal Sosial dan Budaya Keislaman
#    Akreditasi: S2
#    URL: http://ejournal.stainpamekasan.ac.id/index.php/karsa/index
# 690. Jurnal Penelitian
#    Akreditasi: S2
#    URL: http://e-journal.iainpekalongan.ac.id/index.php/Penelitian
# 691. ASEAN Marketing Journal (AMJ)
#    Akreditasi: S2
#    URL: http://journal.ui.ac.id/amj
# 692. Jurnal Masyarakat dan Budaya
#    Akreditasi: S2
#    URL: http://jmb.lipi.go.id/index.php/jmb
# 693. Jurnal FIlsafat
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/wisdom/index
# 694. Jurnal Penginderaan Jauh dan pengolahan Data Citra Digital
#    Akreditasi: S2
#    URL: http://jurnal.lapan.go.id/index.php/jurnal_inderaja
# 695. Esensia : Jurnal Ilmu-Ilmu Ushuluddin
#    Akreditasi: S2
#    URL: http://ejournal.uin-suka.ac.id/ushuluddin/esensia
# 696. Animal Production
#    Akreditasi: S2
#    URL: http://animalproduction.net
# 697. Economics and Finance in Indonesia
#    Akreditasi: S2
#    URL: http://efi.ui.ac.id/index.php/efi
# 698. Vektora : Jurnal Vektor dan Reservoir Penyakit
#    Akreditasi: S2
#    URL: http://ejournal.litbang.depkes.go.id/index.php/vk
# 699. Suhuf: Jurnal Pengkajian Al-Quran dan Budaya
#    Akreditasi: S2
#    URL: http://jurnalsuhuf.kemenag.go.id/index.php/suhuf
# 700. Jurnal Studi Pemerintahan
#    Akreditasi: S2
#    URL: http://journal.umy.ac.id/index.php/jsp
# 701. Jurnal Keperawatan Soedirman (The Soedirman Journal of Nursing)
#    Akreditasi: S2
#    URL: http://jks.fikes.unsoed.ac.id/index.php/jks/issue/archive
# 702. Public Health and Preventive Medicine Archive
#    Akreditasi: S2
#    URL: https://ojs.unud.ac.id/index.php/phpma
# 703. Jurnal Pendidikan Sains Indonesia (Indonesian Journal of Science Education)
#    Akreditasi: S2
#    URL: http://jurnal.unsyiah.ac.id/JPSI
# 704. Jurnal Kajian Informasi & Perpustakaan
#    Akreditasi: S2
#    URL: http://jurnal.unpad.ac.id/jkip/index
# 705. Jurnal Kependudukan Indonesia
#    Akreditasi: S2
#    URL: http://ejurnal.kependudukan.lipi.go.id/index.php/jki
# 706. Jurnal Ilmiah Islam Futura
#    Akreditasi: S2
#    URL: https://jurnal.ar-raniry.ac.id/index.php/islamfutura
# 707. Aceh International Journal of Science and Technology
#    Akreditasi: S2
#    URL: http://jurnal.unsyiah.ac.id/AIJST
# 708. Yustisia
#    Akreditasi: S2
#    URL: https://jurnal.uns.ac.id/yustisia
# 709. Miqot : Jurnal Ilmu-ilmu Keislaman
#    Akreditasi: S2
#    URL: http://jurnalmiqotojs.uinsu.ac.id/index.php/jurnalmiqot
# 710. AKSIOMA: Jurnal Program Studi Pendidikan Matematika
#    Akreditasi: S2
#    URL: http://fkip.ummetro.ac.id/journal/index.php/matematika
# 711. Masyarakat Indonesia
#    Akreditasi: S2
#    URL: http://jmi.ipsk.lipi.go.id/index.php/jmiipsk
# 712. Buletin Kebun Raya (The Botanic Garden Bulletin)
#    Akreditasi: S2
#    URL: http://jurnal.krbogor.lipi.go.id
# 713. Resital: Jurnal Seni Pertunjukan (Journal of Performing Arts)
#    Akreditasi: S2
#    URL: http://journal.isi.ac.id/index.php/resital
# 714. Treubia
#    Akreditasi: S2
#    URL: http://e-journal.biologi.lipi.go.id/index.php/treubia
# 715. Kalam
#    Akreditasi: S2
#    URL: http://ejournal.radenintan.ac.id/index.php/KALAM
# 716. Annales Bogorienses
#    Akreditasi: S2
#    URL: http://jurnal.biotek.lipi.go.id/index.php/annales
# 717. Journal of Islamic Architecture
#    Akreditasi: S2
#    URL: http://ejournal.uin-malang.ac.id/index.php/JIA
# 718. Indonesia Law Review
#    Akreditasi: S2
#    URL: http://ilrev.ui.ac.id/index.php/home/index
# 719. Jurnal Pengkajian dan Pengembangan Teknologi Pertanian
#    Akreditasi: S2
#    URL: http://ejurnal.litbang.pertanian.go.id/index.php/jpengkajian
# 720. Jurnal Wasian : Wahana Informasi Penelitian Kehutanan
#    Akreditasi: S2
#    URL: http://ejournal.forda-mof.org/ejournal-litbang/index.php/JWAS
# 721. PALASTReN: Jurnal Studi Gender
#    Akreditasi: S2
#    URL: http://journal.stainkudus.ac.id/index.php/Palastren
# 722. Linguistik Indonesia
#    Akreditasi: S2
#    URL: http://www.linguistik-indonesia.org/?lang=id
# 723. Jurnal Riset Industri Perdagangan
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/jri
# 724. Journal of Educational, Health, Community Psychology
#    Akreditasi: S2
#    URL: http://journal.uad.ac.id/index.php/Psychology/index
# 725. Geoplanning: Journal of Geomatics and Planning
#    Akreditasi: S2
#    URL: http://ejournal.undip.ac.id/index.php/geoplanning/
# 726. Zoo Indonesia
#    Akreditasi: S2
#    URL: http://e-journal.biologi.lipi.go.id/index.php/zoo_indonesia/index
# 727. Bahasa dan Seni : Jurnal Bahasa, Sastra, Seni, dan Pengajarannya
#    Akreditasi: S2
#    URL: http://journal2.um.ac.id/index.php/jbs
# 728. Justicia Islamica
#    Akreditasi: S2
#    URL: http://jurnal.stainponorogo.ac.id/index.php/justicia/index
# 729. Indonesia Journal of Biomedical Science
#    Akreditasi: S2
#    URL: http://ijbs-udayana.org/
# 730. Jurnal Akuntansi dan Bisnis
#    Akreditasi: S2
#    URL: http://jab.fe.uns.ac.id/index.php/jab/index
# 731. International Journal of Remote Sensing and Earth Sciences
#    Akreditasi: S2
#    URL: http://jurnal.lapan.go.id/index.php/ijreses
# 732. Berkala Ilmu Kedokteran (Journal of the Medical Sciences)
#    Akreditasi: S2
#    URL: http://jurnal.ugm.ac.id/bik/
# 733. Agro Ekonomi
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/jae/index
# 734. Health Science Journal of Indonesia
#    Akreditasi: S2
#    URL: http://ejournal.litbang.depkes.go.id/index.php/HSJI
# 735. Jurnal Ekonomi dan Pembangunan
#    Akreditasi: S2
#    URL: http://jurnalekonomi.lipi.go.id/index.php/JEP/index
# 736. Jurnal Geologi dan Sumberdaya Mineral
#    Akreditasi: S2
#    URL: http://jgsm.geologi.esdm.go.id/index.php/JGSM
# 737. Indonesian Capital Market Review (ICMR)
#    Akreditasi: S2
#    URL: http://journal.ui.ac.id/icmr
# 738. Jurnal Sains dan Teknologi Nuklir Indonesia
#    Akreditasi: S2
#    URL: http://jurnal.batan.go.id/index.php/jstni
# 739. LiNGUA: Jurnal Ilmu Bahasa dan Sastra
#    Akreditasi: S2
#    URL: http://ejournal.uin-malang.ac.id/index.php/humbud
# 740. Jurnal Sains Dirgantara
#    Akreditasi: S2
#    URL: http://jurnal.lapan.go.id/index.php/jurnal_sains
# 741. Indonesian Journal of Applied Physics
#    Akreditasi: S2
#    URL: https://jurnal.uns.ac.id/ijap/index
# 742. Adabiyyat : Jurnal Bahasa dan Sastra
#    Akreditasi: S2
#    URL: http://ejournal.uin-suka.ac.id/adab/Adabiyyat
# 743. Jurnal Theologia
#    Akreditasi: S2
#    URL: http://journal.walisongo.ac.id/index.php/teologia
# 744. Jurnal Kajian Bali (Journal of Bali Studies)
#    Akreditasi: S2
#    URL: http://ojs.unud.ac.id/index.php/kajianbali
# 745. JLBG: Jurnal Lingkungan dan Bencana Geologi
#    Akreditasi: S2
#    URL: http://jlbg.geologi.esdm.go.id/index.php/jlbg
# 746. Jurnal Hukum Internasional : Indonesian Journal of International Law
#    Akreditasi: S2
#    URL: http://ijil.ui.ac.id/index.php/home
# 747. Pandecta : Jurnal Penelitian Ilmu Hukum (Research Law Journal)
#    Akreditasi: S2
#    URL: https://journal.unnes.ac.id/nju/index.php/pandecta
# 748. Journal of Urban Society's Arts
#    Akreditasi: S2
#    URL: http://journal.isi.ac.id/index.php/JOUSA
# 749. ECSOFiM (Economic and Social of Fisheries and Marine)
#    Akreditasi: S2
#    URL: https://ecsofim.ub.ac.id/index.php/ecsofim
# 750. APMBA (Asia Pacific Management and Business Application)
#    Akreditasi: S2
#    URL: http://apmba.ub.ac.id/index.php/apmba
# 751. International Business and Accounting Research Journal
#    Akreditasi: S2
#    URL: http://ibarj.com/index.php/ibarj
# 752. Tataloka
#    Akreditasi: S2
#    URL: http://ejournal2.undip.ac.id/index.php/tataloka/issue/archive
# 753. Jurnal Studi Komunikasi dan Media
#    Akreditasi: S2
#    URL: https://jurnal.kominfo.go.id/index.php/jskm
# 754. Journal of Dentomaxillofacial Science
#    Akreditasi: S2
#    URL: https://jdmfs.org/index.php/jdmfs
# 755. Jurnal Kimia dan Kemasan
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/jkk/index
# 756. Eksplorium : Buletin Pusat Pengembangan Bahan Galian Nuklir
#    Akreditasi: S2
#    URL: http://jurnal.batan.go.id/index.php/eksplorium
# 757. Poetika : Jurnal Ilmu Sastra
#    Akreditasi: S2
#    URL: http://jurnal.ugm.ac.id/poetika
# 758. SHARE Jurnal Ekonomi dan Keuangan Islam
#    Akreditasi: S2
#    URL: http://jurnal.ar-raniry.ac.id/index.php/Share/index
# 759. Jurnal Ilmiah Kursor
#    Akreditasi: S2
#    URL: http://kursorjournal.org/index.php/kursor
# 760. Celt : A Journal of Culture, English Language Teaching and Literature
#    Akreditasi: S2
#    URL: http://journal.unika.ac.id/index.php/celt
# 761. Mutawatir : Jurnal Keilmuan Tafsir Hadith
#    Akreditasi: S2
#    URL: http://jurnalfuf.uinsby.ac.id/index.php/mutawatir
# 762. Negara Hukum: Membangun Hukum untuk Keadilan dan Kesejahteraan
#    Akreditasi: S2
#    URL: http://jurnal.dpr.go.id/index.php/hukum
# 763. Jurnal Pemuliaan Tanaman Hutan
#    Akreditasi: S2
#    URL: http://ejournal.forda-mof.org/ejournal-litbang/index.php/JPTH
# 764. Acta Veterinaria Indonesiana
#    Akreditasi: S2
#    URL: http://journal.ipb.ac.id/index.php/actavetindones/index
# 765. AL-Albab
#    Akreditasi: S2
#    URL: http://jurnaliainpontianak.or.id/index.php/alalbab/issue/archive
# 766. Jurnal Teknosains
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/teknosains
# 767. International Journal of Agriculture System (IJAS)
#    Akreditasi: S2
#    URL: http://pasca.unhas.ac.id/ojs/index.php/ijas/issue/archive
# 768. Jurnal Yudisial
#    Akreditasi: S2
#    URL: http://jurnal.komisiyudisial.go.id/
# 769. Istinbath
#    Akreditasi: S2
#    URL: http://ejurnal.iainmataram.ac.id/index.php/istinbath
# 770. JAS (Journal of ASEAN Studies)
#    Akreditasi: S2
#    URL: https://journal.binus.ac.id/index.php/jas/index
# 771. Padjadjaran Journal of Dentistry
#    Akreditasi: S2
#    URL: http://jurnal.unpad.ac.id/pjd
# 772. Jurnal Teknologi Dirgantara
#    Akreditasi: S2
#    URL: http://jurnal.lapan.go.id/index.php/jurnal_tekgan
# 773. Al-Ahwal : Jurnal Hukum Keluarga Islam
#    Akreditasi: S2
#    URL: http://ejournal.uin-suka.ac.id/syariah/Ahwal
# 774. Jurnal Riset Teknologi Pencegahan Pencemaran Industri
#    Akreditasi: S2
#    URL: http://jrtppi.id
# 775. Teknologi Indonesia
#    Akreditasi: S2
#    URL: http://www.jti.lipi.go.id/index.php/JTI
# 776. Ekuilibrium : Jurnal Ilmiah Bidang Ilmu Ekonomi
#    Akreditasi: S2
#    URL: http://journal.umpo.ac.id/index.php/ekuilibrium
# 777. Indonesian Journal of Obstetrics and Gynecology (Majalah Obstetri dan Ginekologi Indonesia)
#    Akreditasi: S2
#    URL: http://inajog.com/index.php/journal
# 778. Refleksi Hukum : Jurnal Ilmu Hukum
#    Akreditasi: S2
#    URL: http://ejournal.uksw.edu/refleksihukum
# 779. Jurnal Kardiologi Indonesia
#    Akreditasi: S2
#    URL: http://ijconline.id/index.php/ijc
# 780. Jurnal Penelitian Komunikasi
#    Akreditasi: S2
#    URL: http://bppkibandung.id/index.php/jpk/index
# 781. Lembaran Publikasi Lemigas
#    Akreditasi: S2
#    URL: http://www.journal.lemigas.esdm.go.id/index.php/LPMGB
# 782. Majalah Obstetri dan Ginekologi
#    Akreditasi: S2
#    URL: http://e-journal.unair.ac.id/index.php/MOG
# 783. Jurnal Industri Hasil Perkebunan (Journal of Plantation Based Industry)
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/bbihp/index
# 784. Musawa : Jurnal Studi Gender dan Islam
#    Akreditasi: S2
#    URL: http://ejournal.uin-suka.ac.id/pusat/MUSAWA
# 785. Bulletin of the Marine Geology
#    Akreditasi: S2
#    URL: http://ejournal.mgi.esdm.go.id/index.php/bomg
# 786. Biopropal Industri
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/biopropal
# 787. Warta IHP (Warta Industri Hasil Pertanian)
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/ihp
# 788. Metalingua
#    Akreditasi: S2
#    URL: http://metalingua.kemdikbud.go.id/jurnal/index.php/metalingua
# 789. Jurisdictie : Jurnal Hukum dan Syariah
#    Akreditasi: S2
#    URL: http://ejournal.uin-malang.ac.id/index.php/jurisdictie
# 790. Jurnal Magister Hukum Udayana (Udayana Master Law Journal)
#    Akreditasi: S2
#    URL: https://ojs.unud.ac.id/index.php/jmhu/index
# 791. Jurnal Ilmu dan Teknologi Hasil ternak
#    Akreditasi: S2
#    URL: http://jitek.ub.ac.id/index.php/jitek
# 792. Jurnal Penelitian Karet
#    Akreditasi: S2
#    URL: http://ejournal.puslitkaret.co.id/index.php/jpk
# 793. Amerta
#    Akreditasi: S2
#    URL: http://jurnalarkeologi.kemdikbud.go.id/index.php/amerta
# 794. Jurnal Neuroanestesi Indonesia
#    Akreditasi: S2
#    URL: http://ojs.inasnacc.org/ojs/index.php/jni
# 795. Scientific Contributions Oil and Gas
#    Akreditasi: S2
#    URL: http://www.journal.lemigas.esdm.go.id/ojs/index.php/SCOG
# 796. Khazanah: Jurnal Studi Islam dan Humaniora
#    Akreditasi: S2
#    URL: http://jurnal.uin-antasari.ac.id/index.php/khazanah
# 797. Amwaluna : Jurnal Ekonomi dan Keuangan Syariah
#    Akreditasi: S2
#    URL: https://ejournal.unisba.ac.id/index.php/amwaluna
# 798. Indonesian Journal of Cancer
#    Akreditasi: S2
#    URL: http://indonesianjournalofcancer.or.id/e-journal/index.php/ijoc
# 799. Journal of Wetlands Environmental Management
#    Akreditasi: S2
#    URL: http://ijwem.unlam.ac.id/index.php/ijwem
# 800. Metalurgi
#    Akreditasi: S2
#    URL: http://ejurnalmaterialmetalurgi.com/index.php/metalurgi
# 801. Kalpataru
#    Akreditasi: S2
#    URL: http://jurnalarkeologi.kemdikbud.go.id/
# 802. Al-Ihkam: Jurnal Hukum dan Pranata Sosial
#    Akreditasi: S2
#    URL: http://ejournal.stainpamekasan.ac.id/index.php/alihkam
# 803. Widyaparwa (Jurnal Ilmiah Kebahasaan dan Kesastraan)
#    Akreditasi: S2
#    URL: http://www.widyaparwa.com/index.php/widyaparwa
# 804. Ilmu Ushuluddin
#    Akreditasi: S2
#    URL: http://journal.uinjkt.ac.id/index.php/ilmu-ushuluddin/index
# 805. JRP (Jurnal Review Politik)
#    Akreditasi: S2
#    URL: http://jurnalpolitik.uinsby.ac.id/index.php/jrp/index
# 806. Jurnal Sosial Ekonomi Pekerjaan Umum
#    Akreditasi: S2
#    URL: http://jurnalsosekpu.pu.go.id/index.php/sosekpu
# 807. Heritage of Nusantara: International Journal of Religious Literature and Heritage
#    Akreditasi: S2
#    URL: http://jurnallektur.kemenag.go.id/index.php/heritage/
# 808. Walennae: Jurnal Arkeologi Sulawesi Selatan dan Tenggara
#    Akreditasi: S2
#    URL: https://walennae.kemdikbud.go.id/index.php/walennae
# 809. Jurnal Teknologi Bahan dan Barang Teknik
#    Akreditasi: S2
#    URL: https://ejournal.b4t.go.id/index.php/JTBBT
# 810. Jurnal Keramik dan Gelas Indonesia
#    Akreditasi: S2
#    URL: http://ejournal.kemenperin.go.id/jkgi
# 811. Purbawidya : Jurnal Penelitian dan Pengembangan Arkeologi
#    Akreditasi: S2
#    URL: http://purbawidya.kemdikbud.go.id
# 812. Jurnal Pendidikan Progresif
#    Akreditasi: S2
#    URL: http://jurnal.fkip.unila.ac.id/index.php/jpp/index
# 813. Majalah Anestesia dan Critical Care
#    Akreditasi: S2
#    URL: http://newjournal.perdatin.org/index.php/macc
# 814. Jurnal Kebijakan Sosial Ekonomi Kelautan dan Perikanan
#    Akreditasi: S2
#    URL: http://ejournal-balitbang.kkp.go.id/index.php/jkse
# 815. Jurnal Biotek Medisiana Indonesia
#    Akreditasi: S2
#    URL: http://ejournal.litbang.depkes.go.id/index.php/jbmi
# 816. Instrumentasi
#    Akreditasi: S2
#    URL: http://jurnalinstrumentasi.metrologi.lipi.go.id/index.php/ji
# 817. Papua : Jurnal Penelitian Arkeologi Papua dan Papua Barat
#    Akreditasi: S2
#    URL: https://jurnalarkeologipapua.kemdikbud.go.id/index.php/jpap
# 818. Pangan
#    Akreditasi: S2
#    URL: http://www.jurnalpangan.com/index.php/pangan
# 819. Indonesian Journal of Urology
#    Akreditasi: S2
#    URL: http://juri.urologi.or.id/index.php/juri
# 820. Jurnal Bimas Islam
#    Akreditasi: S2
#    URL: https://bimasislam.kemenag.go.id/site/informasi/jurnal
# 821. Jnana budaya
#    Akreditasi: S2
#    URL: https://jurnalbpnbbali.kemdikbud.go.id/jurnal/index.php/Jnana
# 822. Jurnal Ilmu Komunikasi
#    Akreditasi: S2
#    URL: http://jurnal.upnyk.ac.id/index.php/komunikasi/index
# 823. Jurnal Aplikasi Statistika dan Komputasi Statistik
#    Akreditasi: S2
#    URL: https://jurnal.stis.ac.id/index.php/jurnalasks
# 824. Sawerigading
#    Akreditasi: S2
#    URL: http://sawerigading.kemdikbud.go.id/
# 825. Matrik: Jurnal Manajemen, Strategi Bisnis, dan Kewirausahaan
#    Akreditasi: S2
#    URL: http://ojs.unud.ac.id/index.php/jmbk
# 826. TSAQAFAH
#    Akreditasi: S2
#    URL: http://ejournal.unida.gontor.ac.id/index.php/tsaqafah
# 827. Floribunda
#    Akreditasi: S2
#    URL: http://www.ptti.or.id/journal
# 828. Majalah Polimer Indonesia
#    Akreditasi: S2
#    URL: http://hpi-polimer.org/publishing/11-majalah-polimer-indonesia-mpi
# 829. Jantra
#    Akreditasi: S2
#    URL: https://kebudayaan.kemdikbud.go.id/bpnbyogyakarta/category/karya-tulis/jantra/
# 830. Jurnal Penelitian Transportasi Darat
#    Akreditasi: S2
#    URL: http://balitbanghub.dephub.go.id/ojs/index.php/jurnaldarat
# 831. Neurona
#    Akreditasi: S2
#    URL: http://www.neurona.web.id/home.do
# 832. Jurnal Hukum Bisnis
#    Akreditasi: S2
#    URL: http://www.jurnalhukumbisnis.com
# 833. Majalah Polimer Indonesia
#    Akreditasi: S2
#    URL: http://hpi-polimer.org/publishing/11-majalah-polimer-indonesia-mpi
# 834. Jurnal Bisnis Strategi
#    Akreditasi: S3
#    URL: https://ejournal.undip.ac.id/index.php/jbs/index
# 835. Jurnal Bisnis dan Akuntansi
#    Akreditasi: S3
#    URL: https://jurnaltsm.id/index.php/JBA
# 836. SOCA: Jurnal Sosial Ekonomi Pertanian
#    Akreditasi: S3
#    URL: https://ojs.unud.ac.id/index.php/soca/index
# 837. BIOEDUSCIENCE : Jurnal Pendidikan Biologi & Sains
#    Akreditasi: S3
#    URL: https://journal.uhamka.ac.id/index.php/bioeduscience
# 838. Jurnal Ilmu Sosial dan Humaniora
#    Akreditasi: S3
#    URL: http://ejournal.undiksha.ac.id/index.php/JISH/
# 839. Journal of Medives : Journal of Mathematics Education IKIP Veteran Semarang
#    Akreditasi: S3
#    URL: http://e-journal.ivet.ac.id/index.php/matematika/
# 840. J@ti Undip: Jurnal Teknik Industri
#    Akreditasi: S3
#    URL: http://ejournal.undip.ac.id/index.php/jgti/index
# 841. E-Jurnal Medika Udayana
#    Akreditasi: S3
#    URL: http://ojs.unud.ac.id/index.php/eum
# 842. JNPM (JURNAL NASIONAL PENDIDIKAN MATEMATIKA)
#    Akreditasi: S3
#    URL: http://jurnal.unswagati.ac.id/index.php/JNPM/index
# 843. CESS (Journal of Computer Engineering, System and Science)
#    Akreditasi: S3
#    URL: http://jurnal.unimed.ac.id/2012/index.php/cess
# 844. JBMP (Jurnal Bisnis, Manajemen Dan Perbankan)
#    Akreditasi: S3
#    URL: http://ojs.umsida.ac.id/index.php/JBMP
# 845. JKBM (JURNAL KONSEP BISNIS DAN MANAJEMEN)
#    Akreditasi: S3
#    URL: http://ojs.uma.ac.id/index.php/bisman
# 846. PrimaryEdu : Journal of Primary Education
#    Akreditasi: S3
#    URL: http://e-journal.stkipsiliwangi.ac.id/index.php/primaryedu
# 847. Edukasi Islami : Jurnal Pendidikan Islam
#    Akreditasi: S3
#    URL: http://jurnal.staialhidayahbogor.ac.id/index.php/ei
# 848. Jurnal Geografi Gea
#    Akreditasi: S3
#    URL: https://ejournal.upi.edu/index.php/gea
# 849. Jurnal Informasi, Perpajakan, Akuntansi, dan Keuangan Publik
#    Akreditasi: S3
#    URL: https://www.trijurnal.lemlit.trisakti.ac.id/jipak
# 850. IndoMath: Indonesia Mathematics Education
#    Akreditasi: S3
#    URL: http://jurnal.ustjogja.ac.id/index.php/Indomath
# 851. Formatif : Jurnal Ilmiah Pendidikan MIPA
#    Akreditasi: S3
#    URL: http://journal.lppmunindra.ac.id/index.php/Formatif
# 852. Mosharafa: Jurnal Pendidikan Matematika
#    Akreditasi: S3
#    URL: http://e-mosharafa.org/index.php/mosharafa
# 853. JIPF (Jurnal Ilmu Pendidikan Fisika)
#    Akreditasi: S3
#    URL: http://journal.stkipsingkawang.ac.id/index.php/JIPF
# 854. Jurnal Pendidikan Fisika dan Keilmuan (JPFK)
#    Akreditasi: S3
#    URL: http://e-journal.unipma.ac.id/index.php/JPFK/index
# 855. Biosfer: Jurnal Tadris Biologi
#    Akreditasi: S3
#    URL: http://ejournal.radenintan.ac.id/index.php/biosfer
# 856. Jurnal ECODEMICA
#    Akreditasi: S3
#    URL: http://ejournal.bsi.ac.id/ejurnal/index.php/ecodemica/about/contact
# 857. JALIE: Journal of Applied Linguistics and Islamic Education
#    Akreditasi: S3
#    URL: http://ejournal.inkafa.ac.id/index.php/jalie-inkafa/index
# 858. The Journal of Society and Media
#    Akreditasi: S3
#    URL: https://journal.unesa.ac.id/index.php/jsm
# 859. Kalamatika : Jurnal Pendidikan Matematika
#    Akreditasi: S3
#    URL: http://kalamatika.matematika-uhamka.com/index.php/kmk/issue/archive
# 860. Jurnal Psikologi
#    Akreditasi: S3
#    URL: http://ejournal.uin-suska.ac.id/index.php/psikologi
# 861. Jurnal Penjaminan Mutu
#    Akreditasi: S3
#    URL: http://ejournal.ihdn.ac.id/index.php/JPM
# 862. Seloka: Jurnal Pendidikan Bahasa dan Sastra Indonesia
#    Akreditasi: S3
#    URL: https://journal.unnes.ac.id/sju/index.php/seloka
# 863. Jurnal Benefita : Ekonomi Pembangungan, Manajemen Bisnis dan Akuntansi
#    Akreditasi: S3
#    URL: http://ejournal.kopertis10.or.id/index.php/benefita
# 864. Scholaria : Jurnal Pendidikan dan Kebudayaan
#    Akreditasi: S3
#    URL: http://ejournal.uksw.edu/scholaria/index
# 865. Journal of Science Learning
#    Akreditasi: S3
#    URL: https://ejournal.upi.edu/index.php/jslearning
# 866. Desimal: Jurnal Matematika
#    Akreditasi: S3
#    URL: http://ejournal.radenintan.ac.id/index.php/desimal/index
# 867. SJME (Supremum Journal of Mathematics Education)
#    Akreditasi: S3
#    URL: http://journal.unsika.ac.id/index.php/supremum
# 868. Jurnal Media Informatika Budidarma
#    Akreditasi: S3
#    URL: http://ejurnal.stmik-budidarma.ac.id/
# 869. Jurnal Riset Akuntansi Dan Bisnis Airlangga
#    Akreditasi: S3
#    URL: http://jraba.org/journal/index.php/jraba
# 870. Inovasi : Jurnal Ekonomi, Keuangan dan Manajemen
#    Akreditasi: S3
#    URL: http://journal.feb.unmul.ac.id/index.php/INOVASI
# 871. JIPI (Jurnal IPA dan Pembelajaran IPA)
#    Akreditasi: S3
#    URL: http://jurnal.unsyiah.ac.id/JIPI
# 872. MaPan : Jurnal Matematika dan Pembelajaran
#    Akreditasi: S3
#    URL: http://journal.uin-alauddin.ac.id/index.php/Mapan/index
# 873. Jurnal Inspirasi Pendidikan
#    Akreditasi: S3
#    URL: http://ejournal.unikama.ac.id/index.php/jrnspirasi/issue/archive
# 874. Sospol : Jurnal Sosial Politik
#    Akreditasi: S3
#    URL: http://ejournal.umm.ac.id/index.php/sospol/index
# 875. Jurnal Ilmiah Manajemen dan Bisnis
#    Akreditasi: S3
#    URL: http://jurnal.umsu.ac.id/index.php/mbisnis/index
# 876. Jurnal Hukum Islam Fakultas Syari'ah
#    Akreditasi: S3
#    URL: http://e-journal.iainpekalongan.ac.id/index.php/jhi
# 877. Semantik
#    Akreditasi: S3
#    URL: http://e-journal.stkipsiliwangi.ac.id/index.php/semantik/index
# 878. Jurnal IQRA' : Kajian Ilmu Pendidikan
#    Akreditasi: S3
#    URL: http://journal.iaimnumetrolampung.ac.id/index.php/ji
# 879. Transmisi
#    Akreditasi: S3
#    URL: https://ejournal.undip.ac.id/index.php/transmisi
# 880. Jurnal Sains dan Teknologi
#    Akreditasi: S3
#    URL: https://ejournal.unri.ac.id/index.php/JST
# 881. JST (Jurnal Sains dan Teknologi)
#    Akreditasi: S3
#    URL: http://ejournal.undiksha.ac.id/index.php/JST/
# 882. Jurnal Farmasi Galenika (Galenika Journal of Pharmacy)
#    Akreditasi: S3
#    URL: https://bestjournal.untad.ac.id/index.php/Galenika
# 883. Metana : Media Komunikasi Rekayasa Proses dan Teknologi Tepat Guna
#    Akreditasi: S3
#    URL: https://ejournal.undip.ac.id/index.php/metana
# 884. NUMERICAL : Jurnal Matematika dan Pendidikan Matematika
#    Akreditasi: S3
#    URL: http://journal.iaimnumetrolampung.ac.id/index.php/numerical/issue/view/7
# 885. Curricula : Journal of Teaching and Learning
#    Akreditasi: S3
#    URL: http://ejournal.kopertis10.or.id/index.php/curricula/index
# 886. International Journal of Research in Counseling and Education
#    Akreditasi: S3
#    URL: http://ppsfip.ppj.unp.ac.id/index.php/ijrice/index
# 887. InfoTekJar : Jurnal Nasional Informatika dan Teknologi Jaringan
#    Akreditasi: S3
#    URL: http://jurnal.uisu.ac.id/index.php/infotekjar
# 888. Journal of Maternal and Child Health
#    Akreditasi: S3
#    URL: http://www.thejmch.com
# 889. Higeia : Journal of Public Health Research and Development
#    Akreditasi: S3
#    URL: http://journal.unnes.ac.id/sju/index.php/higeia
# 890. Istawa: Jurnal Pendidikan Islam
#    Akreditasi: S3
#    URL: http://journal.umpo.ac.id/index.php/istawa/index
# 891. Jurnal Pendidikan (Teori dan Praktik)
#    Akreditasi: S3
#    URL: http://journal.unesa.ac.id/index.php/jp
# 892. Jurnal Teknologi Perikanan dan Kelautan
#    Akreditasi: S3
#    URL: http://jurnal.ipb.ac.id/index.php/jtpk/index
# 893. Jurnal Akuntansi dan Auditing
#    Akreditasi: S3
#    URL: https://ejournal.undip.ac.id/index.php/akuditi
# 894. JIPVA (Jurnal Pendidikan IPA Veteran)
#    Akreditasi: S3
#    URL: http://e-journal.ivet.ac.id/index.php/jipva/index
# 895. Mimbar Sekolah Dasar
#    Akreditasi: S3
#    URL: http://ejournal.upi.edu/index.php/mimbar/index
# 896. Jurnal Promosi Kesehatan Indonesia
#    Akreditasi: S3
#    URL: https://ejournal.undip.ac.id/index.php/jpki
# 897. Media Ekonomi dan Manajemen
#    Akreditasi: S3
#    URL: http://jurnal.untagsmg.ac.id/index.php/fe/index
# 898. JP2SD (Jurnal Pemikiran dan Pengembangan Sekolah Dasar)
#    Akreditasi: S3
#    URL: http://ejournal.umm.ac.id/index.php/jp2sd
# 899. Techno.Com: Jurnal Teknologi Informasi
#    Akreditasi: S3
#    URL: http://publikasi.dinus.ac.id/index.php/technoc/index
# 900. Berita Kedokteran Masyarakat
#    Akreditasi: S3
#    URL: https://jurnal.ugm.ac.id/bkm
# 901. SOSIO-DIDAKTIKA: Social Science Education Journal
#    Akreditasi: S3
#    URL: http://journal.uinjkt.ac.id/index.php/SOSIO-FITK
# 902. Geosfera Indonesia
#    Akreditasi: S3
#    URL: https://jurnal.unej.ac.id/index.php/GEOSI
# 903. Jurnal Keperawatan Silampari
#    Akreditasi: S3
#    URL: https://journal.ipm2kpe.or.id/index.php/JKS
# 904. Jurnal Bimbingan dan Konseling Terapan
#    Akreditasi: S3
#    URL: https://ojs.unpatti.ac.id/index.php/bkt
# 905. JIPM (Jurnal Ilmiah Pendidikan Matematika)
#    Akreditasi: S3
#    URL: http://e-journal.unipma.ac.id/index.php/jipm
# 906. Esensi: Jurnal Bisnis dan Manajemen
#    Akreditasi: S3
#    URL: http://journal.uinjkt.ac.id/index.php/esensi/index
# 907. Premiere Educandum : Jurnal Pendidikan Dasar dan Pembelajaran
#    Akreditasi: S3
#    URL: http://e-journal.unipma.ac.id/index.php/PE/
# 908. Jurnal Natural
#    Akreditasi: S3
#    URL: http://www.jurnal.unsyiah.ac.id/natural/issue/archive
# 909. jurnal ilmiah ekonomi dan bisnis
#    Akreditasi: S3
#    URL: https://ejurnal.unilak.ac.id/index.php/JIEB
# 910. Jurnal Riset dan Kajian Pendidikan Fisika
#    Akreditasi: S3
#    URL: http://journal.uad.ac.id/index.php/JRKPF/index
# 911. Jurnal Minds: Manajemen Ide dan Inspirasi
#    Akreditasi: S3
#    URL: http://journal.uin-alauddin.ac.id/index.php/minds
# 912. Refleksi Edukatika : Jurnal Ilmiah Kependidikan
#    Akreditasi: S3
#    URL: https://jurnal.umk.ac.id/index.php/RE/index
# 913. Vidyottama Sanatana: International Journal of Hindu Science and Religious Studies
#    Akreditasi: S3
#    URL: http://ejournal.ihdn.ac.id/index.php/IJHSRS
# 914. Teorema: Teori dan Riset Matematika
#    Akreditasi: S3
#    URL: https://jurnal.unigal.ac.id/index.php/teorema/index
# 915. Polyglot: Jurnal Ilmiah
#    Akreditasi: S3
#    URL: http://ojs.uph.edu/index.php/PJI/index
# 916. LLT Journal: A Journal on Language and Language Teaching
#    Akreditasi: S3
#    URL: http://e-journal.usd.ac.id/index.php/LLT/index
# 917. Jurnal Informatika: Jurnal Pengembangan IT
#    Akreditasi: S3
#    URL: http://ejournal.poltektegal.ac.id/index.php/informatika
# 918. Jurnal Komunikasi
#    Akreditasi: S3
#    URL: https://journal.untar.ac.id/index.php/komunikasi
# 919. JURTEKSI (Jurnal Teknologi dan Sistem Informasi)
#    Akreditasi: S3
#    URL: https://jurnal.stmikroyal.ac.id/index.php/jurteksi
# 920. Jurnal Akuntansi Keuangan dan Bisnis
#    Akreditasi: S3
#    URL: https://jurnal.pcr.ac.id/index.php/jakb
# 921. Ijaz Arabi : Journal of Arabic Learning
#    Akreditasi: S3
#    URL: http://ejournal.uin-malang.ac.id/index.php/ijazarabi/index
# 922. Jurnal Endurance: Kajian Ilmiah Problema Kesehatan
#    Akreditasi: S3
#    URL: http://ejournal.kopertis10.or.id/index.php/endurance/index
# 923. Jurnal Visi Ilmu Pendidikan
#    Akreditasi: S3
#    URL: http://jurnal.untan.ac.id/index.php/jvip/index
# 924. Evangelikal: Jurnal Teologi Injili dan Pembinaan Warga Jemaat
#    Akreditasi: S3
#    URL: http://journal.sttsimpson.ac.id/index.php/EJTI
# 925. ProTVF: Jurnal Kajian Televisi dan Film
#    Akreditasi: S3
#    URL: http://journal.unpad.ac.id/protvf
# 926. IJFAC (Indonesian Journal of Fundamental and Applied Chemistry)
#    Akreditasi: S3
#    URL: http://www.ijfac.unsri.ac.id/index.php/ijfac/index
# 927. INTENSIF: Jurnal Ilmiah Penelitian Teknologi dan Penerapan Sistem Informasi
#    Akreditasi: S3
#    URL: http://ojs.unpkediri.ac.id/index.php/intensif
# 928. INVOTEK: Jurnal Inovasi Vokasional dan Teknologi
#    Akreditasi: S3
#    URL: http://invotek.ppj.unp.ac.id/index.php/invotek
# 929. Jurnal Pendidikan Edutama
#    Akreditasi: S3
#    URL: http://ejurnal.ikippgribojonegoro.ac.id/index.php/JPE/index
# 930. JOIV : International Journal on Informatics Visualization
#    Akreditasi: S3
#    URL: http://joiv.org/
# 931. Majalah Ilmiah Biologi Biosfera: A Scientific Journal
#    Akreditasi: S3
#    URL: https://journal.bio.unsoed.ac.id/index.php/biosfera/index
# 932. JHSS (Journal of Humanities and Social Studies)
#    Akreditasi: S3
#    URL: https://journal.unpak.ac.id/index.php/jhss
# 933. Jurnal Analisa
#    Akreditasi: S3
#    URL: http://journal.uinsgd.ac.id/index.php/analisa
# 934. Jurnal Teknik Informatika
#    Akreditasi: S3
#    URL: http://journal.uinjkt.ac.id/index.php/ti
# 935. Riau Journal of Empowerment
#    Akreditasi: S3
#    URL: http://raje.unri.ac.id/index.php/raje
# 936. JPIB : Jurnal Psikologi Islam dan Budaya
#    Akreditasi: S3
#    URL: http://journal.uinsgd.ac.id/index.php/jpib
# 937. Jurnal Teknologi
#    Akreditasi: S3
#    URL: https://jurnal.umj.ac.id/index.php/jurtek
# 938. JOURNAL OF ICSAR
#    Akreditasi: S3
#    URL: http://journal2.um.ac.id/index.php/icsar
# 939. Jurnal Transformatika
#    Akreditasi: S3
#    URL: http://journals.usm.ac.id/index.php/transformatika/index
# 940. JUPIIS: Jurnal Pendidikan Ilmu-ilmu Sosial
#    Akreditasi: S3
#    URL: http://jurnal.unimed.ac.id/2012/index.php/jupiis
# 941. Jurnal Agroteknologi
#    Akreditasi: S3
#    URL: http://jurnal.unej.ac.id/index.php/JAGT/index
# 942. CAUCHY: Jurnal Matematika Murni dan Aplikasi
#    Akreditasi: S3
#    URL: http://ejournal.uin-malang.ac.id/index.php/Math
# 943. JITCE (Journal of Information Technology and Computer Engineering)
#    Akreditasi: S3
#    URL: http://jitce.fti.unand.ac.id/index.php/JITCE
# 944. TIFBR (Tazkia Islamic Finance and Business Review)
#    Akreditasi: S3
#    URL: http://tifbr-tazkia.org/index.php/TIFBR/index
# 945. Jurnal Gantang
#    Akreditasi: S3
#    URL: http://ojs.umrah.ac.id/index.php/gantang/index
# 946. Jurnal Organisasi dan Manajemen
#    Akreditasi: S3
#    URL: http://jurnal.ut.ac.id/JOM
# 947. SINTECH (Science and Information Technology) Journal
#    Akreditasi: S3
#    URL: https://jurnal.stiki-indonesia.ac.id/index.php/sintechjournal
# 948. Pilar Nusa Mandiri : Journal of Computing and Information System
#    Akreditasi: S3
#    URL: http://ejournal.nusamandiri.ac.id/index.php/pilar
# 949. Al-Tadzkiyyah: Jurnal Pendidikan Islam
#    Akreditasi: S3
#    URL: http://ejournal.radenintan.ac.id/index.php/tadzkiyyah/index
# 950. PCD JOURNAL
#    Akreditasi: S3
#    URL: https://journal.ugm.ac.id/pcd
# 951. IKAT: The Indonesian Journal of Southeast Asian Studies
#    Akreditasi: S3
#    URL: https://jurnal.ugm.ac.id/ikat
# 952. Jurnal Rona Teknik Pertanian
#    Akreditasi: S3
#    URL: http://jurnal.unsyiah.ac.id/RTP
# 953. Indonesian EFL Journal
#    Akreditasi: S3
#    URL: https://journal.uniku.ac.id/index.php/IEFLJ
# 954. Tadrib: Jurnal Pendidikan Agama Islam
#    Akreditasi: S3
#    URL: http://jurnal.radenfatah.ac.id/index.php/Tadrib/index
# 955. Jurnal Manajemen Komunikasi
#    Akreditasi: S3
#    URL: http://jurnal.unpad.ac.id/manajemen-komunikasi
# 956. Jurnal Ilmu Perilaku
#    Akreditasi: S3
#    URL: http://jip.fk.unand.ac.id/index.php/jip
# 957. Cogito Smart Journal
#    Akreditasi: S3
#    URL: http://cogito.unklab.ac.id/index.php/cogito
# 958. Counsellia: Jurnal Bimbingan dan Konseling
#    Akreditasi: S3
#    URL: http://e-journal.unipma.ac.id/index.php/JBK/index
# 959. Journal of Nonformal Education
#    Akreditasi: S3
#    URL: https://journal.unnes.ac.id/nju/index.php/jne/index
# 960. Journal of Honai Math
#    Akreditasi: S3
#    URL: http://journalfkipunipa.org/index.php/jhm
# 961. LENTERA: Jurnal Ilmu Dakwah dan Komunikasi
#    Akreditasi: S3
#    URL: https://journal.iain-samarinda.ac.id/index.php/lentera
# 962. KEMBARA: Jurnal Keilmuan Bahasa, Sastra, dan Pengajarannya
#    Akreditasi: S3
#    URL: http://ejournal.umm.ac.id/index.php/kembara/article/view/2322
# 963. ISM (Intisari Sains Medis) : Jurnal Kedokteran
#    Akreditasi: S3
#    URL: https://isainsmedis.id/index.php/ism
# 964. Edukasi: Jurnal Pendidikan dan Pengajaran
#    Akreditasi: S3
#    URL: http://jurnal.radenfatah.ac.id/index.php/edukasi
# 965. Jurnal Studi Agama dan Masyarakat
#    Akreditasi: S3
#    URL: http://e-journal.iain-palangkaraya.ac.id/index.php/jsam
# 966. Jurnal Hutan Tropis
#    Akreditasi: S3
#    URL: http://ppjp.unlam.ac.id/journal/index.php/jht/index
# 967. LINGUA: Journal of Language, Literature and Teaching
#    Akreditasi: S3
#    URL: http://lingua.pusatbahasa.or.id/index.php/lingua/
# 968. ZISWAF : Jurnal Zakat dan Wakaf
#    Akreditasi: S3
#    URL: http://journal.stainkudus.ac.id/index.php/Ziswaf
# 969. International Journal of Islamic Business and Economics (IJIBEC)
#    Akreditasi: S3
#    URL: http://e-journal.iainpekalongan.ac.id/index.php/IJIBEC
# 970. Lentera Pendidikan : Jurnal Ilmu Tarbiyah dan Keguruan
#    Akreditasi: S3
#    URL: http://journal.uin-alauddin.ac.id/index.php/lentera_pendidikan
# 971. IT Journal Research and Development
#    Akreditasi: S3
#    URL: http://journal.uir.ac.id/index.php/ITJRD
# 972. Jurnal Ilmiah Potensia
#    Akreditasi: S3
#    URL: https://ejournal.unib.ac.id/index.php/potensia
# 973. Jurnal Kajian Wilayah
#    Akreditasi: S3
#    URL: http://jkw.psdr.lipi.go.id/index.php/jkw
# 974. JITK (Jurnal Ilmu Pengetahuan dan Teknologi Komputer)
#    Akreditasi: S3
#    URL: http://ejournal.nusamandiri.ac.id/index.php/jitk
# 975. Unnes Journal of Mathematics Education
#    Akreditasi: S3
#    URL: https://journal.unnes.ac.id/sju/index.php/ujme
# 976. iMProvement
#    Akreditasi: S3
#    URL: http://journal.unj.ac.id/unj/index.php/improvement/index
# 977. ILKOM Jurnal Ilmiah
#    Akreditasi: S3
#    URL: http://jurnal.fikom.umi.ac.id/index.php/ILKOM
# 978. BHUMI: Jurnal Agraria dan Pertanahan
#    Akreditasi: S3
#    URL: https://jurnalbhumi.stpn.ac.id/index.php/JB
# 979. Jurnal Penelitian Pendidikan IPA (JPPIPA)
#    Akreditasi: S3
#    URL: http://jppipa.unram.ac.id/index.php/jppipa
# 980. Jurnal Psikologi Integratif
#    Akreditasi: S3
#    URL: http://ejournal.uin-suka.ac.id/isoshum/PI
# 981. Jurnal Akuntabilitas Manajemen Pendidikan
#    Akreditasi: S3
#    URL: http://journal.uny.ac.id/index.php/jamp
# 2265. Jurnal Biosains
#    Akreditasi: S4
#    URL: http://jurnal.unimed.ac.id/2012/index.php/biosains
# 2266. Jurnal Manajemen
#    Akreditasi: S4
#    URL: http://ejournal.atmajaya.ac.id/index.php/JM
# 2267. Jurnal Komunika: Jurnal Komunikasi, Media dan Informatika
#    Akreditasi: S4
#    URL: https://jurnal.kominfo.go.id/index.php/komunika
# 2268. Logista: Jurnal Ilmiah Pengabdian kepada Masyarakat
#    Akreditasi: S4
#    URL: http://logista.fateta.unand.ac.id/index.php/logista
# 2269. Jurnal Produksi Tanaman
#    Akreditasi: S4
#    URL: http://protan.studentjournal.ub.ac.id/index.php/protan
# 2270. Jurnal Pengabdian Pada Masyarakat
#    Akreditasi: S4
#    URL: http://ppm.ejournal.id
# 2271. Agregat: Jurnal Ekonomi dan Bisnis
#    Akreditasi: S4
#    URL: http://journal.uhamka.ac.id/index.php/agregat/index
# 2272. Media Keperawatan Indonesia
#    Akreditasi: S4
#    URL: https://jurnal.unimus.ac.id/index.php/mki
# 2273. Intiqad: Jurnal Agama dan Pendidikan Islam
#    Akreditasi: S4
#    URL: http://jurnal.umsu.ac.id/index.php/intiqad/index
# 2274. Medina-Te : Jurnal Studi Islam
#    Akreditasi: S4
#    URL: http://jurnal.radenfatah.ac.id/index.php/medinate
# 2275. Jurnal Saintekom (Sain, Teknologi, Komputer dan Manajeman)
#    Akreditasi: S4
#    URL: http://stmikplk.ac.id/jurnal/index.php/saintekom
# 2276. Global Review of Islamic Economics and Business
#    Akreditasi: S4
#    URL: http://ejournal.uin-suka.ac.id/febi/grieb
# 2277. Al-Falah: Journal of Islamic Economics
#    Akreditasi: S4
#    URL: http://journal.staincurup.ac.id/index.php/alfalah
# 2278. JITE (Journal of Informatics and Telecommunication Engineering)
#    Akreditasi: S4
#    URL: https://ojs.uma.ac.id/index.php/jite/index
# 2279. Martabat: Jurnal Perempuan dan Anak
#    Akreditasi: S4
#    URL: http://ejournal.iain-tulungagung.ac.id/index.php/martabat
# 2280. Journal of Community Engagement in Health
#    Akreditasi: S4
#    URL: https://jceh.org/index.php/JCEH
# 2281. Gorontalo Journal of Government and Political Studies
#    Akreditasi: S4
#    URL: http://jurnal.unigo.ac.id/index.php/gjgops
# 2282. At-Tadbir : jurnal ilmiah manajemen
#    Akreditasi: S4
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-35-7783eb45378c> in <module>()
#      40             print("   Akreditasi: " + journal_info.text)
#      41
# ---> 42             r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
#      43             if r.status_code==200:
#      44                 bsoup = BeautifulSoup(r.text, 'html.parser')
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %% [markdown]
# ## Lanjutan dari disconnect

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import json
import re


s = requests.Session()
r = s.get('http://sinta.ristekbrin.go.id/journals')
bsoup = BeautifulSoup(r.text, 'html.parser')
lastpage = 1

if r.status_code==200:
    # mencari halaman terakhir
    for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
        for litag in ultag.find_all('li'):
            for links in litag.find_all('a', href=True):
                # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                query = urlparse(links['href']).query
                lastpage = re.compile('page=(\d+)').findall(query)
    lastpage = lastpage[0]
    print("Bismillah, lets start scrapping " + lastpage + " pages of Sinta journals")

    # looping halaman Sinta sampai lastpage
    page = 1
    journal_no = (page-1) * 9 + 1
    while page < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 620:
        #    break
        
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(page) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            journal_link = journal.find('a')
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            print(str(journal_no) + ". " + journal_link.text)
            print("   Akreditasi: " + journal_info.text)
            
            r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            if r.status_code==200:
                bsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                journal_urls = bsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                print("   URL: " + journal_url)
            journal_no = journal_no +1
            
        page = page + 1



# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# Bismillah, lets start scrapping 461 pages of Sinta journals
# 91. Jurnal Teknologi Lingkungan
#    Akreditasi: S2
#    URL: http://ejurnal.bppt.go.id/index.php/JTL/issue/archive
# 92. Majalah Geografi Indonesia
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/mgi
# 93. Al-Iqtishad : Jurnal Ilmu Ekonomi Syariah (Journal of Islamic Economics)
#    Akreditasi: S2
#    URL: http://journal.uinjkt.ac.id/index.php/iqtishad
# 94. Buletin Psikologi
#    Akreditasi: S2
#    URL: https://jurnal.ugm.ac.id/buletinpsikologi
# 95. Jurnal Ilmiah Perikanan dan Kelautan
#    Akreditasi: S2
#    URL: https://e-journal.unair.ac.id/JIPK
# 96. Jurnal ASET (Akuntansi Riset)
#    Akreditasi: S2
#    URL: http://ejournal.upi.edu/index.php/aset
# 97. Jurnal Legislasi Indonesia
#    Akreditasi: S2
#    URL: http://e-jurnal.peraturan.go.id/index.php/jli/index
# 98. Jurnal Pendidikan dan Kebudayaan
#    Akreditasi: S2
#    URL: http://jurnaldikbud.kemdikbud.go.id/index.php/jpnk
# 99. SCIENTIFIC DENTAL JOURNAL
#    Akreditasi: S2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6290984bb6d9> in <module>()
#      40             print("   Akreditasi: " + journal_info.text)
#      41
# ---> 42             r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
#      43             if r.status_code==200:
#      44                 bsoup = BeautifulSoup(r.text, 'html.parser')
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     490         """
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#     494         else:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     669                 if self.chunk_left == 0:
#     670                     break
# --> 671                 chunk = self._handle_chunk(amt)
#     672                 decoded = self._decode(chunk, decode_content=decode_content,
#     673                                        flush_decoder=False)
#
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in _handle_chunk(self, amt)
#     624             returned_chunk = value
#     625         else:  # amt > self.chunk_left
# --> 626             returned_chunk = self._fp._safe_read(self.chunk_left)
#     627             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     628             self.chunk_left = None
#
# /usr/lib/python3.6/http/client.py in _safe_read(self, amt)
#     620         s = []
#     621         while amt > 0:
# --> 622             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     623             if not chunk:
#     624                 raise IncompleteRead(b''.join(s), amt)
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Sinta Hunter v1
#
# Skrip pertama yang saya tulis, sekedar utk memastikan bahwa teknik scrapping bisa digunakan

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import json
import re


s = requests.Session()
r = s.get('http://sinta.ristekbrin.go.id/journals')
bsoup = BeautifulSoup(r.text, 'html.parser')
lastpage = 1

if r.status_code==200:
    # mencari halaman terakhir
    for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
        for litag in ultag.find_all('li'):
            for links in litag.find_all('a', href=True):
                # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                query = urlparse(links['href']).query
                lastpage = re.compile('page=(\d+)').findall(query)
    lastpage = lastpage[0]
    print("Bismillah, lets start sracpping " + lastpage + " pages of Sinta journals")

    # looping halaman Sinta sampai lastpage
    page = 1
    journal_no = 1
    while page < int(lastpage) + 1:
        # development purpose
        if page == 5:
            break

        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(page) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("a", {"class":"text-blue"})
        for journal in journals_in_this_page:
            print(str(journal_no)+". "+journal.text) # print journal name
            print(journal['href']) 
            #r = s.get('http://sinta.ristekbrin.go.id'+journal['href'])
            #jurnal_soup = BeautifulSoup(r.text, 'html.parser')
            #journal_url = journal_soup.find('a', {"class": ""})
            #print(r.text)
            journal_no = journal_no +1
            
        page = page + 1



# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# Out:
# Bismillah, lets start sracpping 461 pages of Sinta journals
# 1. Jurnal Cakrawala Pendidikan
# /journals/detail/?id=703
# 2. Operations and Supply Chain Management: An International Journal
# /journals/detail/?id=3203
# 3. IJAL (Indonesian Journal of Applied Linguistics)
# /journals/detail/?id=1099
# 4. Journal on Mathematics Education
# /journals/detail/?id=2113
# 5. Buletin Ekonomi Moneter dan Perbankan
# /journals/detail/?id=1103
# 6. Jurnal Pendidikan IPA Indonesia (Indonesian Journal of Science Education)
# /journals/detail/?id=671
# 7. International Journal on Advanced Science, Engineering and Information Technology (IJASEIT)
# /journals/detail/?id=696
# 8. Forest and Society
# /journals/detail/?id=1266
# 9. International Journal of Electrical and Computer Engineering
# /journals/detail/?id=693
# 10. Bulletin of Electrical Engineering and Informatics
# /journals/detail/?id=681
# 11. Journal of the Indonesian Tropical Animal Agriculture
# /journals/detail/?id=678
# 12. Journal of Engineering and Technological Sciences
# /journals/detail/?id=680
# 13. Gadjah Mada International Journal of Business (GamaIJB)
# /journals/detail/?id=665
# 14. Indonesian Journal of Islam and Muslim Societies
# /journals/detail/?id=668
# 15. IJAIN (International Journal of Advances in Intelligent Informatics)
# /journals/detail/?id=1017
# 16. Indonesian Journal of Science and Technology
# /journals/detail/?id=3794
# 17. Journal of Mathematical and Fundamental Sciences
# /journals/detail/?id=667
# 18. International Journal of Evaluation and Research in Education (IJERE)
# /journals/detail/?id=3539
# 19. Biodiversitas : Journal of Biolodical Diversity
# /journals/detail/?id=694
# 20. Studia Islamika
# /journals/detail/?id=684
# 21. International Journal of Renewable Energy Development : JRED
# /journals/detail/?id=918
# 22. Indonesian Journal of Electrical Engineering and Computer Science
# /journals/detail/?id=697
# 23. Tropical Animal Science Journal
# /journals/detail/?id=677
# 24. Indonesian Journal of Electrical Engineering and Informatics
# /journals/detail/?id=1095
# 25. TELKOMNIKA (Telecommunication Computing Electronics and Control)
# /journals/detail/?id=664
# 26. IJOG : Indonesian Journal on Geoscience
# /journals/detail/?id=896
# 27. QIJIS (Qudus International Journal Of Islamic Studies)
# /journals/detail/?id=1322
# 28. AGRIVITA, Journal of Agricultural Science (AJAS)
# /journals/detail/?id=682
# 29. HAYATI Journal of Biosciences
# /journals/detail/?id=683
# 30. Journal of Degraded and Mining Lands Management
# /journals/detail/?id=920
# 31. JSP (Jurnal Ilmu Sosial dan Ilmu Politik)
# /journals/detail/?id=865
# 32. Indonesian Journal of Chemistry
# /journals/detail/?id=662
# 33. Atom Indonesia
# /journals/detail/?id=675
# 34. BIOTROPIA
# /journals/detail/?id=676
# 35. Al-Jami'ah: Journal of Islamic Studies
# /journals/detail/?id=685
# 36. Bulletin of Chemical Reaction Engineering & Catalysis
# /journals/detail/?id=691
# 37. Journal of Regional and City Planning
# /journals/detail/?id=832
# 38. Indonesian Journal of Biotechnology
# /journals/detail/?id=732
# 39. Indonesian Journal of Forestry Research
# /journals/detail/?id=1718
# 40. Indonesian Journal of Geography
# /journals/detail/?id=669

# %% [markdown]
# # Versi save to Colab
#
# [Back to Home](#scrollTo=YaazQkWbIXnv)

# %%
#@Sinta Hunter by beta.uliansyah@pknstan.ac.id
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse 
import re
import csv
from datetime import date
import time
from google.colab import drive
drive.mount('/content/drive')

def sinta_lastpage():
    """
    Find last page of Sinta list
    """
    s = requests.Session()
    r = s.get('http://sinta.ristekbrin.go.id/journals')
    bsoup = BeautifulSoup(r.text, 'html.parser')
    lastpage = 1

    if r.status_code==200:
        # mencari halaman terakhir
        for ultag in bsoup.find_all('ul', {'class': 'top-paging'}):
            for litag in ultag.find_all('li'):
                for links in litag.find_all('a', href=True):
                    # parse_qs is not working well in Python 3 at the time I wrote this code. so i use regex
                    # .query or [4], Read: https://docs.python.org/3/library/urllib.parse.html
                    query = urlparse(links['href']).query
                    lastpage = re.compile('page=(\d+)').findall(query)
        lastpage = int(lastpage[0])
    return lastpage

def sinta_readpages(startpage=1, lastpage=sinta_lastpage()):
    # prepare file name with date and write header
    filename = "sinta-data-" + str(date.today()) + ".csv"
    header_row = ['journal_no', 'journal_id', 'journal_name', 'journal_accreditation', 'journal_url']
    with open("/content/drive/My Drive/sinta-tools/"+filename, mode='w') as sintacsv_file:
        sintacsv_writer = csv.writer(sintacsv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        sintacsv_writer.writerow(header_row)
    print(header_row)

    # looping halaman Sinta dari startpage sampai lastpage
    return_value = []
    currentpage = startpage
    journal_no = (startpage-1) * 9 + 1
    i = 0
    while currentpage < int(lastpage) + 1:
        # development purpose, uncomment two lines following to limit number of pages to be scrapped
        #if page == 620:
        #    break

        # session
        s = requests.Session()
        r = s.get('http://sinta.ristekbrin.go.id/journals?page='+ str(currentpage) +'&sort=impact')
        bsoup = BeautifulSoup(r.text, 'html.parser')
        journals_in_this_page = bsoup.find_all("dl", {"class":"uk-description-list-line"})
        for journal in journals_in_this_page:
            # mencari nama jurnal
            journal_link = journal.find('a')

            #mencari akreditasi
            journal_info = journal.find('span', attrs={'class' :'index-val-small', 'style': re.compile('color')}) # cari span dengan color apapun
            
            #mencari jurnal ID SINTA: strip all text before = /journals/detail/?id=681
            journal_id = journal_link['href']
            #re.sub(r"^.*(=)", "", journal_id)
            
            # mencari URL jurnal
            # jika error connection, tunggu bbrp detik (random delay)
            try:
                r = s.get('http://sinta.ristekbrin.go.id'+journal_link['href'])
            except requests.exceptions.ConnectionError as e:
                pass
            except Exception as e:
                logger.error(e)
                randomtime = random.randint(1,5)
                logger.warn('ERROR - Retrying again website %s, retrying in %d secs' % (url, randomtime))
                time.sleep(randomtime)
                continue
                    
            if r.status_code==200:
                jsoup = BeautifulSoup(r.text, 'html.parser')
                # cari <a href="http://journal.unhas.ac.id/index.php/fs/index" ><i class="uk-icon-globe uk-text-primary"></i> Website</a> | 
                # mencari URL
                journal_urls = jsoup.find_all('a')
                for journal_url in journal_urls:
                    if journal_url.find(text=re.compile("Website")):
                        journal_url = journal_url['href']
                        break
                #print("   URL: " + journal_url)
            # prepare result_data
            result_data = [journal_no, journal_id, journal_link.text, journal_info.text, journal_url]
            with open("drive/My Drive/sinta-tools/"+filename, mode='a+') as sintacsv_file:
                sintacsv_writer = csv.writer(sintacsv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                sintacsv_writer.writerow(result_data)
            return_value.append(result_data)
            print(result_data)
            journal_no = journal_no +1
            i += 1
            
        currentpage = currentpage + 1
    return return_value

if __name__ == "__main__":
    start_time = time.time()
    sinta_readpages()
    duration = time.time() - start_time
    print(f"Executed in {duration} seconds")
    # sinta_readpages(startpage=3, lastpage=4)
    # sinta_readpages(7, 8)




# Credits:
# https://stackoverflow.com/questions/11716380/beautifulsoup-extract-text-from-anchor-tag
# https://stackoverflow.com/questions/5815747/beautifulsoup-getting-href
# https://stackoverflow.com/questions/50338108/using-beautifulsoup-in-order-to-find-all-ul-and-li-elements
# https://stackoverflow.com/questions/17246963/how-to-find-all-lis-within-a-specific-ul-class
# https://stackoverflow.com/questions/31958637/beautifulsoup-search-by-text-inside-a-tag
# Out:
# Streaming output truncated to the last 5000 lines.
# [150, '/journals/detail/?id=3050', 'Jurnal Tumbuhan Obat Indonesia', 'S2', 'http://www.b2p2toot.litbang.kemkes.go.id']
# [151, '/journals/detail/?id=941', 'Jurnal Riset Pendidikan Matematika', 'S2', 'http://journal.uny.ac.id/index.php/jrpm']
# [152, '/journals/detail/?id=638', 'Jurnal Obsesi: Jurnal Pendidikan Anak Usia Dini', 'S2', 'http://journal.universitaspahlawan.ac.id/index.php/obsesi']
# [153, '/journals/detail/?id=2783', 'Health Science Journal of Indonesia', 'S2', 'http://ejournal.litbang.depkes.go.id/index.php/HSJI']
# [154, '/journals/detail/?id=955', 'Islamica: Jurnal Studi Keislaman', 'S2', 'http://islamica.uinsby.ac.id/index.php/islamica/index']
# [155, '/journals/detail/?id=3522', 'JIPF (Jurnal Ilmu Pendidikan Fisika)', 'S2', 'http://journal.stkipsingkawang.ac.id/index.php/JIPF']
# [156, '/journals/detail/?id=746', 'Jurnal Penelitian dan Evaluasi Pendidikan', 'S2', 'http://journal.uny.ac.id/index.php/jpep/index']
# [157, '/journals/detail/?id=2250', 'JPBI (JURNAL PENDIDIKAN BIOLOGI INDONESIA)', 'S2', 'http://ejournal.umm.ac.id/index.php/jpbi/index']
# [158, '/journals/detail/?id=872', 'Jurnal Komunikasi ASPIKOM', 'S2', 'http://jurnalaspikom.org/index.php/aspikom']
# [159, '/journals/detail/?id=42', 'Premiere Educandum : Jurnal Pendidikan Dasar dan Pembelajaran', 'S2', 'http://e-journal.unipma.ac.id/index.php/PE/']
# [160, '/journals/detail/?id=2466', "Jurnal IQRA' : Kajian Ilmu Pendidikan", 'S2', 'http://journal.iaimnumetrolampung.ac.id/index.php/ji']
