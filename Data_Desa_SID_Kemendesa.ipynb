# %% [markdown]
# <a href="https://colab.research.google.com/github/BetaUliansyah/Sandbox/blob/main/Data_Desa_SID_Kemendesa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get all Desa IDS

# %%
Request URL: https://sid.kemendesa.go.id/home/searchByKode?desa=1105072002

# %%
import requests
import json
from bs4 import BeautifulSoup

session = None
def set_global_session():
    global session
    if not session:
        session = requests.Session()

def get_provinsi():
    url = 'https://sid.kemendesa.go.id/'
    results = {}
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            allprovinsi = bsoup.find("select", {"id":"provinsi"}) # print this var is 
            for provinsi in allprovinsi.find_all("option"):
                results[provinsi['value']] = provinsi.text
            return results

def get_pemda(provinsi='11'):
    url = 'https://sid.kemendesa.go.id/home/listKab'
    results = {}
    with session.post(url, data = {'id_provinsi' : provinsi}) as response:
        if len(response.text) != 0:
            allpemda = BeautifulSoup(json.loads(response.text)['list_kab'], 'html.parser')
            for pemda in allpemda.find_all("option"):
                results[pemda['value']] = pemda.text
            return results

def get_kecamatan(pemda='1105'):
    url = 'https://sid.kemendesa.go.id/home/listKec'
    results = {}
    with session.post(url, data = {'id_kab' : pemda}) as response:
        if len(response.text) != 0:
            allkecamatan = BeautifulSoup(json.loads(response.text)['list_kec'], 'html.parser')
            for kecamatan in allkecamatan.find_all("option"):
                results[kecamatan['value']] = kecamatan.text
            return results

def get_desa(kecamatan='1105'):
    # 1105: get all desa in a pemda
    # 111206: get all desa in a kecamatan
    url = 'https://sid.kemendesa.go.id/home/listDesa'
    results = {}
    with session.post(url, data = {'id_kec' : kecamatan}) as response:
        if len(response.text) != 0:
            alldesa = BeautifulSoup(json.loads(response.text)['list_desa'], 'html.parser')
            for desa in alldesa.find_all("option"):
                results[desa['value']] = desa.text
            return results

if __name__ == "__main__":
    set_global_session()
    print(len(get_desa('111206')))
    print(get_desa('111206'))
# Out:
# 15
# {'0': '- Pilih Desa -', '1112062013': 'ALUE DAWAH', '1112062004': 'ALUE JEUREJAK', '1112062006': 'ALUE PEUNAWA', '1112062005': 'BLANG DALAM', '1112062008': 'BLANG RAJA', '1112062014': 'COT SEUMANTOK', '1112062003': 'GUNUNG SAMARINDA', '1112062002': 'IE MIRAH', '1112062012': 'LHOK GAYO', '1112062007': 'PANTE CERMIN', '1112062001': 'PANTE RAKYAT', '1112062009': 'RUKOEN DAME', '1112062010': 'SIMPANG GADENG', '1112062011': 'TELADAN JAYA'}

# %%
import requests
import json
from bs4 import BeautifulSoup
import re

session = None
def set_global_session():
    global session
    if not session:
        session = requests.Session()

def get_provinsi():
    url = 'https://sid.kemendesa.go.id/'
    results = {}
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            allprovinsi = bsoup.find("select", {"id":"provinsi"}) # print this var is 
            for provinsi in allprovinsi.find_all("option"):
                results[provinsi['value']] = provinsi.text
            return results

def get_pemda(provinsi='11'):
    url = 'https://sid.kemendesa.go.id/home/listKab'
    results = {}
    with session.post(url, data = {'id_provinsi' : provinsi}) as response:
        if len(response.text) != 0:
            allpemda = BeautifulSoup(json.loads(response.text)['list_kab'], 'html.parser')
            for pemda in allpemda.find_all("option"):
                results[pemda['value']] = pemda.text
            return results

def get_kecamatan(pemda='1105'):
    url = 'https://sid.kemendesa.go.id/home/listKec'
    results = {}
    with session.post(url, data = {'id_kab' : pemda}) as response:
        if len(response.text) != 0:
            allkecamatan = BeautifulSoup(json.loads(response.text)['list_kec'], 'html.parser')
            for kecamatan in allkecamatan.find_all("option"):
                results[kecamatan['value']] = kecamatan.text
            return results

def get_desa(kecamatan='1105'):
    # 1105: get all desa in a pemda
    # 111206: get all desa in a kecamatan
    url = 'https://sid.kemendesa.go.id/home/listDesa'
    results = {}
    with session.post(url, data = {'id_kec' : kecamatan}) as response:
        if len(response.text) != 0:
            alldesa = BeautifulSoup(json.loads(response.text)['list_desa'], 'html.parser')
            for desa in alldesa.find_all("option"):
                results[desa['value']] = desa.text
            return results

def get_deskripsidesa(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/searchByKode?desa=' + desa
    # url = 'https://sid.kemendesa.go.id/home/deskripsi/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            deskripsi_nama_desa = bsoup.find('th', text = re.compile('Desa')).findNext('th').findNext('th').text
            deskripsi_kec = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_prov = bsoup.find('td', text = re.compile('Provinsi')).findNext('td').findNext('td').text
            deskripsi_kades = bsoup.find('td', text = re.compile('Nama Kepala Desa')).findNext('td').findNext('td').text
            deskripsi_jeniskel = bsoup.find('td', text = re.compile('Jenis Kelamin Kepala Desa')).findNext('td').findNext('td').text
            deskripsi_rpjmdes = bsoup.find('td', text = re.compile('Rencana Pembangunan Jangka Menengah Desa \(RPJM Desa\) yang berlaku')).findNext('td').findNext('td').text
            deskripsi_perioderpjmdes = bsoup.find('td', text = re.compile('Periode RPJM Desa yang berlaku tahun')).findNext('td').findNext('td').text
            deskripsi_kantor = bsoup.find('td', text = re.compile('Keberadaan kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_statuskantor = bsoup.find('td', text = re.compile('Status kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_kondisikantor = bsoup.find('td', text = re.compile('Kondisi kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_lokasikantor = bsoup.find('td', text = re.compile('Lokasi kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_petadesa = bsoup.find('td', text = re.compile('Peta desa yang ditetapkan dalam Peraturan Bupati/Walikota atau Gubernur')).findNext('td').findNext('td').text
            deskripsi_topografi = bsoup.find('td', text = re.compile('Topografi wilayah desa')).findNext('td').findNext('td').text
            deskripsi_mukim = bsoup.find('td', text = re.compile('Keberadaan permukiman penduduk di lereng/puncak')).findNext('td').findNext('td').text
            deskripsi_wilayah = bsoup.find('td', text = re.compile('Wilayah desa terletak di sebanyak')).findNext('td').findNext('td').text
            deskripsi_bataslaut = bsoup.find('td', text = re.compile('Ada wilayah desa yang berbatasan langsung dengan laut')).findNext('td').findNext('td').text
            #deskripsi_sumber = bsoup.find('strong', text = re.compile('Sumber data')).text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            
        results = [deskripsi_nama_desa, deskripsi_kec, deskripsi_pemda, deskripsi_prov, deskripsi_kades, deskripsi_jeniskel, deskripsi_rpjmdes, deskripsi_perioderpjmdes, deskripsi_kantor, deskripsi_statuskantor, deskripsi_kondisikantor, deskripsi_lokasikantor, deskripsi_petadesa, deskripsi_topografi.strip(), deskripsi_mukim.strip(), deskripsi_wilayah, deskripsi_bataslaut.strip()]
        return results

def get_idmdesa(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/idm/' + desa
    # url = 'https://sid.kemendesa.go.id/home/deskripsi/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')

            idm_skor            = bsoup.find('th', text = re.compile('SKOR IDM SAAT INI')).findNext('th').findNext('th').text
            idm_status          = bsoup.find('td', text = re.compile('STATUS IDM')).findNext('td').findNext('td').text
            idm_target          = bsoup.find('td', text = re.compile('TARGET STATUS')).findNext('td').findNext('td').text
            idm_skormin         = bsoup.find('td', text = re.compile('SKOR IDM MINIMAL')).findNext('td').findNext('td').text
            idm_tambah          = bsoup.find('td', text = re.compile('PENAMBAHAN YANG DIBUTUHKAN')).findNext('td').findNext('td').text

            idm_aksessarkes         = bsoup.find('td', text = re.compile('Skor Akses Sarkes'))
            idm_aksessarkes_skor    = idm_aksessarkes.findNext('td').text
            idm_aksessarkes_ket     = idm_aksessarkes.findNext('td').findNext('td').text
            idm_aksessarkes_rekom   = idm_aksessarkes.findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_nilai   = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_pusat   = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_prov    = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_pemda   = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_desa    = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_csr     = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_aksessarkes_lainnya = idm_aksessarkes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_dokter         = bsoup.find('td', text = re.compile('Skor Dokter'))
            idm_dokter_skor    = idm_dokter.findNext('td').text
            idm_dokter_ket     = idm_dokter.findNext('td').findNext('td').text
            idm_dokter_rekom   = idm_dokter.findNext('td').findNext('td').findNext('td').text
            idm_dokter_nilai   = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_pusat   = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_prov    = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_pemda   = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_desa    = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_csr     = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_dokter_lainnya = idm_dokter.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_bidan         = bsoup.find('td', text = re.compile('Skor Bidan'))
            idm_bidan_skor    = idm_bidan.findNext('td').text
            idm_bidan_ket     = idm_bidan.findNext('td').findNext('td').text
            idm_bidan_rekom   = idm_bidan.findNext('td').findNext('td').findNext('td').text
            idm_bidan_nilai   = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_pusat   = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_prov    = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_pemda   = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_desa    = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_csr     = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bidan_lainnya = idm_bidan.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_nakes         = bsoup.find('td', text = re.compile('Skor Nakes Lain'))
            idm_nakes_skor    = idm_nakes.findNext('td').text
            idm_nakes_ket     = idm_nakes.findNext('td').findNext('td').text
            idm_nakes_rekom   = idm_nakes.findNext('td').findNext('td').findNext('td').text
            idm_nakes_nilai   = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_pusat   = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_prov    = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_pemda   = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_desa    = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_csr     = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_nakes_lainnya = idm_nakes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_bpjs         = bsoup.find('td', text = re.compile('Skor Tingkat Kepesertaan BPJS'))
            idm_bpjs_skor    = idm_bpjs.findNext('td').text
            idm_bpjs_ket     = idm_bpjs.findNext('td').findNext('td').text
            idm_bpjs_rekom   = idm_bpjs.findNext('td').findNext('td').findNext('td').text
            idm_bpjs_nilai   = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_pusat   = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_prov    = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_pemda   = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_desa    = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_csr     = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_bpjs_lainnya = idm_bpjs.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_poskesdes         = bsoup.find('td', text = re.compile('Skor Akses Poskesdes'))
            idm_poskesdes_skor    = idm_poskesdes.findNext('td').text
            idm_poskesdes_ket     = idm_poskesdes.findNext('td').findNext('td').text
            idm_poskesdes_rekom   = idm_poskesdes.findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_nilai   = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_pusat   = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_prov    = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_pemda   = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_desa    = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_csr     = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_poskesdes_lainnya = idm_poskesdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text


            idm_posyandu         = bsoup.find('td', text = re.compile('Skor Aktivitas Posyandu'))
            idm_posyandu_skor    = idm_posyandu.findNext('td').text
            idm_posyandu_ket     = idm_posyandu.findNext('td').findNext('td').text
            idm_posyandu_rekom   = idm_posyandu.findNext('td').findNext('td').findNext('td').text
            idm_posyandu_nilai   = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_pusat   = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_prov    = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_pemda   = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_desa    = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_csr     = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_posyandu_lainnya = idm_posyandu.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_sd         = bsoup.find('td', text = re.compile('Skor Akses SD\/MI'))
            idm_sd_skor    = idm_sd.findNext('td').text
            idm_sd_ket     = idm_sd.findNext('td').findNext('td').text
            idm_sd_rekom   = idm_sd.findNext('td').findNext('td').findNext('td').text
            idm_sd_nilai   = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_pusat   = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_prov    = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_pemda   = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_desa    = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_csr     = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sd_lainnya = idm_sd.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_smp         = bsoup.find('td', text = re.compile('Skor Akses SMP\/MTS'))
            idm_smp_skor    = idm_smp.findNext('td').text
            idm_smp_ket     = idm_smp.findNext('td').findNext('td').text
            idm_smp_rekom   = idm_smp.findNext('td').findNext('td').findNext('td').text
            idm_smp_nilai   = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_pusat   = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_prov    = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_pemda   = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_desa    = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_csr     = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_smp_lainnya = idm_smp.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_sma         = bsoup.find('td', text = re.compile('Skor Akses SMA\/SMK'))
            idm_sma_skor    = idm_sma.findNext('td').text
            idm_sma_ket     = idm_sma.findNext('td').findNext('td').text
            idm_sma_rekom   = idm_sma.findNext('td').findNext('td').findNext('td').text
            idm_sma_nilai   = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_pusat   = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_prov    = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_pemda   = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_desa    = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_csr     = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_sma_lainnya = idm_sma.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_paud         = bsoup.find('td', text = re.compile('Skor Ketersediaan PAUD'))
            idm_paud_skor    = idm_paud.findNext('td').text
            idm_paud_ket     = idm_paud.findNext('td').findNext('td').text
            idm_paud_rekom   = idm_paud.findNext('td').findNext('td').findNext('td').text
            idm_paud_nilai   = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_pusat   = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_prov    = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_pemda   = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_desa    = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_csr     = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_paud_lainnya = idm_paud.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_pkbm         = bsoup.find('td', text = re.compile('Skor Ketersediaan PKBM\/ Paket ABC'))
            idm_pkbm_skor    = idm_pkbm.findNext('td').text
            idm_pkbm_ket     = idm_pkbm.findNext('td').findNext('td').text
            idm_pkbm_rekom   = idm_pkbm.findNext('td').findNext('td').findNext('td').text
            idm_pkbm_nilai   = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_pusat   = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_prov    = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_pemda   = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_desa    = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_csr     = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_pkbm_lainnya = idm_pkbm.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_kursus         = bsoup.find('td', text = re.compile('Skor Ketersediaan Kursus'))
            idm_kursus_skor    = idm_kursus.findNext('td').text
            idm_kursus_ket     = idm_kursus.findNext('td').findNext('td').text
            idm_kursus_rekom   = idm_kursus.findNext('td').findNext('td').findNext('td').text
            idm_kursus_nilai   = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_pusat   = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_prov    = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_pemda   = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_desa    = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_csr     = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_kursus_lainnya = idm_kursus.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_perpusdes         = bsoup.find('td', text = re.compile('Skor Ketersediaan Taman Baca/ Perpus Desa'))
            idm_perpusdes_skor    = idm_perpusdes.findNext('td').text
            idm_perpusdes_ket     = idm_perpusdes.findNext('td').findNext('td').text
            idm_perpusdes_rekom   = idm_perpusdes.findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_nilai   = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_pusat   = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_prov    = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_pemda   = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_desa    = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_csr     = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_perpusdes_lainnya = idm_perpusdes.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_gr         = bsoup.find('td', text = re.compile('Skor Kebiasaan Goryong'))
            idm_gr_skor    = idm_gr.findNext('td').text
            idm_gr_ket     = idm_gr.findNext('td').findNext('td').text
            idm_gr_rekom   = idm_gr.findNext('td').findNext('td').findNext('td').text
            idm_gr_nilai   = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_pusat   = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_prov    = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_pemda   = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_desa    = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_csr     = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_gr_lainnya = idm_gr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_frekgr         = bsoup.find('td', text = re.compile('Skor Frekuensi Goryong'))
            idm_frekgr_skor    = idm_frekgr.findNext('td').text
            idm_frekgr_ket     = idm_frekgr.findNext('td').findNext('td').text
            idm_frekgr_rekom   = idm_frekgr.findNext('td').findNext('td').findNext('td').text
            idm_frekgr_nilai   = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_pusat   = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_prov    = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_pemda   = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_desa    = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_csr     = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text
            idm_frekgr_lainnya = idm_frekgr.findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').findNext('td').text

            idm_paud         = bsoup.find('td', text = re.compile('Skor Ketersediaan PAUD'))            


        results = [idm_skor, idm_status, idm_target, idm_skormin, idm_tambah, idm_gr_lainnya.rstrip(), idm_gr_rekom.rstrip()]
        return results

def get_sdgdesa(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/sdgs/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            idm_2020 = bsoup.find('th', text = re.compile('Desa')).findNext('th').findNext('th').text
            ipd_2018 = bsoup.find('th', text = re.compile('Desa')).findNext('th').findNext('th').text
            produk_unggulan = bsoup.find('th', text = re.compile('Desa')).findNext('th').findNext('th').text

            deskripsi_kec = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_prov = bsoup.find('td', text = re.compile('Provinsi')).findNext('td').findNext('td').text
            deskripsi_kades = bsoup.find('td', text = re.compile('Nama Kepala Desa')).findNext('td').findNext('td').text
            deskripsi_jeniskel = bsoup.find('td', text = re.compile('Jenis Kelamin Kepala Desa')).findNext('td').findNext('td').text
            deskripsi_rpjmdes = bsoup.find('td', text = re.compile('Rencana Pembangunan Jangka Menengah Desa \(RPJM Desa\) yang berlaku')).findNext('td').findNext('td').text
            deskripsi_perioderpjmdes = bsoup.find('td', text = re.compile('Periode RPJM Desa yang berlaku tahun')).findNext('td').findNext('td').text
            deskripsi_kantor = bsoup.find('td', text = re.compile('Keberadaan kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_statuskantor = bsoup.find('td', text = re.compile('Status kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_kondisikantor = bsoup.find('td', text = re.compile('Kondisi kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_lokasikantor = bsoup.find('td', text = re.compile('Lokasi kantor kepala desa')).findNext('td').findNext('td').text
            deskripsi_petadesa = bsoup.find('td', text = re.compile('Peta desa yang ditetapkan dalam Peraturan Bupati/Walikota atau Gubernur')).findNext('td').findNext('td').text
            deskripsi_topografi = bsoup.find('td', text = re.compile('Topografi wilayah desa')).findNext('td').findNext('td').text
            deskripsi_mukim = bsoup.find('td', text = re.compile('Keberadaan permukiman penduduk di lereng/puncak')).findNext('td').findNext('td').text
            deskripsi_wilayah = bsoup.find('td', text = re.compile('Wilayah desa terletak di sebanyak')).findNext('td').findNext('td').text
            deskripsi_bataslaut = bsoup.find('td', text = re.compile('Ada wilayah desa yang berbatasan langsung dengan laut')).findNext('td').findNext('td').text
            #deskripsi_sumber = bsoup.find('strong', text = re.compile('Sumber data')).text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            deskripsi_pemda = bsoup.find('td', text = re.compile('Kecamatan')).findNext('td').findNext('td').text
            
        results = [deskripsi_nama_desa, deskripsi_kec, deskripsi_pemda, deskripsi_prov, deskripsi_kades, deskripsi_jeniskel, deskripsi_rpjmdes, deskripsi_perioderpjmdes, deskripsi_kantor, deskripsi_statuskantor, deskripsi_kondisikantor, deskripsi_lokasikantor, deskripsi_petadesa, deskripsi_topografi, deskripsi_mukim, deskripsi_wilayah, deskripsi_bataslaut]
        return results

def get_danadesa(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/dd/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            dd_bsoup = bsoup.find('h2', text = re.compile('Pagu Dana Desa')).findNext('h2').findNext('p').findNext('span')
            dd_2020 = dd_bsoup.text
            dd_2019 = dd_bsoup.findNext('h2').findNext('p').findNext('span').text
            dd_2018 = dd_bsoup.findNext('h2').findNext('h2').findNext('p').findNext('span').text
            
        results = [dd_2020, dd_2019, dd_2018]
        return results

def get_apbdes(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/apbdes/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            dd_bsoup = bsoup.find('h2', text = re.compile('Pagu Dana Desa')).findNext('h2').findNext('p').findNext('span')
            dd_2020 = dd_bsoup.text
            dd_2019 = dd_bsoup.findNext('h2').findNext('p').findNext('span').text
            dd_2018 = dd_bsoup.findNext('h2').findNext('h2').findNext('p').findNext('span').text
            
        results = [dd_2020, dd_2019, dd_2018]
        return results     

def get_bumdes(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/bumdes/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            dd_bsoup = bsoup.find('h2', text = re.compile('Pagu Dana Desa')).findNext('h2').findNext('p').findNext('span')
            dd_2020 = dd_bsoup.text
            dd_2019 = dd_bsoup.findNext('h2').findNext('p').findNext('span').text
            dd_2018 = dd_bsoup.findNext('h2').findNext('h2').findNext('p').findNext('span').text
            
        results = [dd_2020, dd_2019, dd_2018]
        return results     

def get_bltdes(desa='1105072002'):
    url = 'https://sid.kemendesa.go.id/home/bltdes/' + desa
    results = []
    with session.get(url) as response:
        if len(response.text) != 0:
            bsoup = BeautifulSoup(response.text, 'html.parser')
            dd_bsoup = bsoup.find('h2', text = re.compile('Pagu Dana Desa')).findNext('h2').findNext('p').findNext('span')
            dd_2020 = dd_bsoup.text
            dd_2019 = dd_bsoup.findNext('h2').findNext('p').findNext('span').text
            dd_2018 = dd_bsoup.findNext('h2').findNext('h2').findNext('p').findNext('span').text
            
        results = [dd_2020, dd_2019, dd_2018]
        return results           

if __name__ == "__main__":
    set_global_session()
    # print(len(get_datadesa('111206')))
    print(get_deskripsidesa('1105072002'))
    print(get_idmdesa('1105072002'))
    print(get_danadesa('1105072002'))
# Out:
# ['ALUE BAGOK', 'ARONGAN LAMBALEK', 'ARONGAN LAMBALEK', 'ACEH', 'ZAINUDDIN', 'Laki-laki', 'Ada', '2015 hingga 2020', 'Ada', 'Aset desa', 'Layak', 'Di dalam wilayah desa', 'Tidak Ada', 'Dataran', 'Tidak ada', '1 pulau', 'Tidak ada']
# ['0.5565', 'TERTINGGAL', 'BERKEMBANG', '0.5990', '0.0425', '', '-']
# ['791,670,000', '800,642,000', '704,518,000']
